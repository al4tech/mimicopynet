# %%
#mimicopynet!
# %load_ext autoreload

# %%
# %autoreload

# %%
# import fluidsynth に失敗する一部の環境への対策
import sys; sys.__interactivehook__()

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# %matplotlib inline

# %%
import mimicopynet as mcn

# %% [markdown]
# # データの前処理．

# %% [markdown]
# ## (1) MusicNet -> wsh5 形式.

# %% [markdown]
# wsh5 形式の中身は h5.
# 一部だけを高速に読み出せるのが便利なので， wsd (pickle) から乗り換えることにした．

# %%
# mcn.data.musicnet_to_wsh5("/Users/yoshidayuuki/Downloads/musicnet/musicnet.npz", "/Users/yoshidayuuki/Downloads/musicnet/musicnet_metadata.csv", "wsh5", "Solo Piano")
# Out:
#   0%|          | 0/156 [00:00<?, ?it/s]
# processing: id = 1733 ( 1 / 156 )
#   1%|          | 1/156 [00:04<11:17,  4.37s/it]
#     .wave.shape: (1, 24079104) .score.shape: (1, 128, 47030) score_sample.shape: (47030,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1733.h5
# processing: id = 1734 ( 2 / 156 )
#   1%|▏         | 2/156 [00:07<10:01,  3.90s/it]
#     .wave.shape: (1, 14359680) .score.shape: (1, 128, 28047) score_sample.shape: (28047,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1734.h5
# processing: id = 1735 ( 3 / 156 )
#   2%|▏         | 3/156 [00:13<11:49,  4.64s/it]
#     .wave.shape: (1, 31527936) .score.shape: (1, 128, 61578) score_sample.shape: (61578,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1735.h5
# processing: id = 1749 ( 4 / 156 )
#   3%|▎         | 4/156 [00:19<13:00,  5.13s/it]
#     .wave.shape: (1, 30710016) .score.shape: (1, 128, 59981) score_sample.shape: (59981,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1749.h5
# processing: id = 1750 ( 5 / 156 )
#   3%|▎         | 5/156 [00:26<13:57,  5.55s/it]
#     .wave.shape: (1, 34581888) .score.shape: (1, 128, 67543) score_sample.shape: (67543,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1750.h5
# processing: id = 1751 ( 6 / 156 )
#   4%|▍         | 6/156 [00:30<12:54,  5.17s/it]
#     .wave.shape: (1, 20976768) .score.shape: (1, 128, 40971) score_sample.shape: (40971,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1751.h5
# processing: id = 1752 ( 7 / 156 )
#   4%|▍         | 7/156 [00:33<11:06,  4.47s/it]
#     .wave.shape: (1, 15995520) .score.shape: (1, 128, 31242) score_sample.shape: (31242,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1752.h5
# processing: id = 1755 ( 8 / 156 )
#   5%|▌         | 8/156 [00:35<08:59,  3.65s/it]
#     .wave.shape: (1, 10134144) .score.shape: (1, 128, 19794) score_sample.shape: (19794,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1755.h5
# processing: id = 1756 ( 9 / 156 )
#   6%|▌         | 9/156 [00:38<08:47,  3.59s/it]
#     .wave.shape: (1, 16382592) .score.shape: (1, 128, 31998) score_sample.shape: (31998,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1756.h5
# processing: id = 1757 ( 10 / 156 )
#   6%|▋         | 10/156 [00:44<10:38,  4.38s/it]
#     .wave.shape: (1, 31337856) .score.shape: (1, 128, 61207) score_sample.shape: (61207,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1757.h5
# processing: id = 1758 ( 11 / 156 )
#   7%|▋         | 11/156 [00:48<10:22,  4.29s/it]
#     .wave.shape: (1, 20656512) .score.shape: (1, 128, 40345) score_sample.shape: (40345,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1758.h5
# processing: id = 1759 ( 12 / 156 )
#   8%|▊         | 12/156 [00:50<08:19,  3.47s/it]
#     .wave.shape: (1, 8584704) .score.shape: (1, 128, 16767) score_sample.shape: (16767,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1759.h5
# processing: id = 1760 ( 13 / 156 )
#   8%|▊         | 13/156 [00:55<09:35,  4.03s/it]
#     .wave.shape: (1, 28910592) .score.shape: (1, 128, 56466) score_sample.shape: (56466,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1760.h5
# processing: id = 1763 ( 14 / 156 )
#   9%|▉         | 14/156 [01:00<10:18,  4.36s/it]
#     .wave.shape: (1, 26474112) .score.shape: (1, 128, 51708) score_sample.shape: (51708,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1763.h5
# processing: id = 1764 ( 15 / 156 )
#  10%|▉         | 15/156 [01:04<09:56,  4.23s/it]
#     .wave.shape: (1, 19327104) .score.shape: (1, 128, 37749) score_sample.shape: (37749,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1764.h5
# processing: id = 1765 ( 16 / 156 )
#  10%|█         | 16/156 [01:10<11:01,  4.73s/it]
#     .wave.shape: (1, 29837952) .score.shape: (1, 128, 58278) score_sample.shape: (58278,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1765.h5
# processing: id = 1766 ( 17 / 156 )
#  11%|█         | 17/156 [01:14<10:24,  4.50s/it]
#     .wave.shape: (1, 18846720) .score.shape: (1, 128, 36810) score_sample.shape: (36810,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1766.h5
# processing: id = 1768 ( 18 / 156 )
#  12%|█▏        | 18/156 [01:17<08:56,  3.89s/it]
#     .wave.shape: (1, 12827520) .score.shape: (1, 128, 25054) score_sample.shape: (25054,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1768.h5
# processing: id = 1771 ( 19 / 156 )
#  12%|█▏        | 19/156 [01:23<10:43,  4.69s/it]
#     .wave.shape: (1, 28548864) .score.shape: (1, 128, 55760) score_sample.shape: (55760,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1771.h5
# processing: id = 1772 ( 20 / 156 )
#  13%|█▎        | 20/156 [01:27<10:08,  4.47s/it]
#     .wave.shape: (1, 18410112) .score.shape: (1, 128, 35958) score_sample.shape: (35958,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1772.h5
# processing: id = 1773 ( 21 / 156 )
#  13%|█▎        | 21/156 [01:30<08:53,  3.95s/it]
#     .wave.shape: (1, 13555584) .score.shape: (1, 128, 26476) score_sample.shape: (26476,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1773.h5
# processing: id = 1775 ( 22 / 156 )
#  14%|█▍        | 22/156 [01:35<09:47,  4.38s/it]
#     .wave.shape: (1, 25499520) .score.shape: (1, 128, 49804) score_sample.shape: (49804,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1775.h5
# processing: id = 1776 ( 23 / 156 )
#  15%|█▍        | 23/156 [01:42<11:29,  5.18s/it]
#     .wave.shape: (1, 32020992) .score.shape: (1, 128, 62541) score_sample.shape: (62541,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1776.h5
# processing: id = 1777 ( 24 / 156 )
#  15%|█▌        | 24/156 [01:49<12:17,  5.59s/it]
#     .wave.shape: (1, 27760896) .score.shape: (1, 128, 54221) score_sample.shape: (54221,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/1777.h5
# processing: id = 2194 ( 25 / 156 )
#  16%|█▌        | 25/156 [01:50<09:00,  4.12s/it]
#     .wave.shape: (1, 4414464) .score.shape: (1, 128, 8622) score_sample.shape: (8622,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2194.h5
# processing: id = 2195 ( 26 / 156 )
#  17%|█▋        | 26/156 [01:51<06:56,  3.20s/it]
#     .wave.shape: (1, 6840576) .score.shape: (1, 128, 13361) score_sample.shape: (13361,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2195.h5
# processing: id = 2196 ( 27 / 156 )
#  17%|█▋        | 27/156 [01:51<05:09,  2.40s/it]
#     .wave.shape: (1, 3328128) .score.shape: (1, 128, 6501) score_sample.shape: (6501,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2196.h5
# processing: id = 2198 ( 28 / 156 )
#  18%|█▊        | 28/156 [01:53<04:27,  2.09s/it]
#     .wave.shape: (1, 8728704) .score.shape: (1, 128, 17049) score_sample.shape: (17049,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2198.h5
# processing: id = 2200 ( 29 / 156 )
#  19%|█▊        | 29/156 [01:53<03:36,  1.70s/it]
#     .wave.shape: (1, 5006592) .score.shape: (1, 128, 9779) score_sample.shape: (9779,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2200.h5
# processing: id = 2201 ( 30 / 156 )
#  19%|█▉        | 30/156 [01:54<03:08,  1.50s/it]
#     .wave.shape: (1, 5921280) .score.shape: (1, 128, 11565) score_sample.shape: (11565,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2201.h5
# processing: id = 2207 ( 31 / 156 )
#  20%|█▉        | 31/156 [01:55<02:36,  1.25s/it]
#     .wave.shape: (1, 3952512) .score.shape: (1, 128, 7720) score_sample.shape: (7720,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2207.h5
# processing: id = 2208 ( 32 / 156 )
#  21%|██        | 32/156 [01:56<02:18,  1.12s/it]
#     .wave.shape: (1, 5326848) .score.shape: (1, 128, 10404) score_sample.shape: (10404,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2208.h5
# processing: id = 2209 ( 33 / 156 )
#  21%|██        | 33/156 [01:57<02:28,  1.21s/it]
#     .wave.shape: (1, 7090560) .score.shape: (1, 128, 13849) score_sample.shape: (13849,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2209.h5
# processing: id = 2210 ( 34 / 156 )
#  22%|██▏       | 34/156 [01:59<02:37,  1.29s/it]
#     .wave.shape: (1, 7864704) .score.shape: (1, 128, 15361) score_sample.shape: (15361,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2210.h5
# processing: id = 2211 ( 35 / 156 )
#  22%|██▏       | 35/156 [02:01<03:00,  1.49s/it]
#     .wave.shape: (1, 10461312) .score.shape: (1, 128, 20433) score_sample.shape: (20433,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2211.h5
# processing: id = 2212 ( 36 / 156 )
#  23%|██▎       | 36/156 [02:02<02:46,  1.39s/it]
#     .wave.shape: (1, 7630848) .score.shape: (1, 128, 14904) score_sample.shape: (14904,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2212.h5
# processing: id = 2213 ( 37 / 156 )
#  24%|██▎       | 37/156 [02:03<02:23,  1.21s/it]
#     .wave.shape: (1, 5114880) .score.shape: (1, 128, 9990) score_sample.shape: (9990,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2213.h5
# processing: id = 2214 ( 38 / 156 )
#  24%|██▍       | 38/156 [02:03<02:08,  1.08s/it]
#     .wave.shape: (1, 4733568) .score.shape: (1, 128, 9246) score_sample.shape: (9246,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2214.h5
# processing: id = 2215 ( 39 / 156 )
#  25%|██▌       | 39/156 [02:04<02:03,  1.05s/it]
#     .wave.shape: (1, 5134464) .score.shape: (1, 128, 10029) score_sample.shape: (10029,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2215.h5
# processing: id = 2224 ( 40 / 156 )
#  26%|██▌       | 40/156 [02:05<01:58,  1.02s/it]
#     .wave.shape: (1, 4798080) .score.shape: (1, 128, 9372) score_sample.shape: (9372,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/
)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2393.h5
# processing: id = 2404 ( 85 / 156 )
#  54%|█████▍    | 85/156 [03:40<04:06,  3.48s/it]
#     .wave.shape: (1, 17601408) .score.shape: (1, 128, 34378) score_sample.shape: (34378,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2404.h5
# processing: id = 2405 ( 86 / 156 )
#  55%|█████▌    | 86/156 [03:42<03:18,  2.84s/it]
#     .wave.shape: (1, 6084864) .score.shape: (1, 128, 11885) score_sample.shape: (11885,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2405.h5
# processing: id = 2406 ( 87 / 156 )
#  56%|█████▌    | 87/156 [03:47<04:06,  3.57s/it]
#     .wave.shape: (1, 26991360) .score.shape: (1, 128, 52718) score_sample.shape: (52718,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2406.h5
# processing: id = 2410 ( 88 / 156 )
#  56%|█████▋    | 88/156 [03:50<03:44,  3.31s/it]
#     .wave.shape: (1, 13824000) .score.shape: (1, 128, 27000) score_sample.shape: (27000,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2410.h5
# processing: id = 2411 ( 89 / 156 )
#  57%|█████▋    | 89/156 [03:51<02:56,  2.63s/it]
#     .wave.shape: (1, 5692032) .score.shape: (1, 128, 11118) score_sample.shape: (11118,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2411.h5
# processing: id = 2422 ( 90 / 156 )
#  58%|█████▊    | 90/156 [03:53<02:40,  2.43s/it]
#     .wave.shape: (1, 10652544) .score.shape: (1, 128, 20806) score_sample.shape: (20806,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2422.h5
# processing: id = 2423 ( 91 / 156 )
#  58%|█████▊    | 91/156 [03:55<02:35,  2.38s/it]
#     .wave.shape: (1, 13129344) .score.shape: (1, 128, 25644) score_sample.shape: (25644,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2423.h5
# processing: id = 2424 ( 92 / 156 )
#  59%|█████▉    | 92/156 [03:57<02:16,  2.13s/it]
#     .wave.shape: (1, 8941824) .score.shape: (1, 128, 17465) score_sample.shape: (17465,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2424.h5
# processing: id = 2436 ( 93 / 156 )
#  60%|█████▉    | 93/156 [04:03<03:35,  3.42s/it]
#     .wave.shape: (1, 30181248) .score.shape: (1, 128, 58948) score_sample.shape: (58948,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2436.h5
# processing: id = 2441 ( 94 / 156 )
#  60%|██████    | 94/156 [04:11<04:54,  4.76s/it]
#     .wave.shape: (1, 35055360) .score.shape: (1, 128, 68468) score_sample.shape: (68468,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2441.h5
# processing: id = 2442 ( 95 / 156 )
#  61%|██████    | 95/156 [04:13<03:52,  3.82s/it]
#     .wave.shape: (1, 7719552) .score.shape: (1, 128, 15078) score_sample.shape: (15078,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2442.h5
# processing: id = 2443 ( 96 / 156 )
#  62%|██████▏   | 96/156 [04:22<05:30,  5.50s/it]
#     .wave.shape: (1, 45649152) .score.shape: (1, 128, 89159) score_sample.shape: (89159,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2443.h5
# processing: id = 2444 ( 97 / 156 )
#  62%|██████▏   | 97/156 [04:29<05:51,  5.96s/it]
#     .wave.shape: (1, 33986304) .score.shape: (1, 128, 66380) score_sample.shape: (66380,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2444.h5
# processing: id = 2471 ( 98 / 156 )
#  63%|██████▎   | 98/156 [04:32<04:59,  5.16s/it]
#     .wave.shape: (1, 20001024) .score.shape: (1, 128, 39065) score_sample.shape: (39065,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/
)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2555.h5
# processing: id = 2556 ( 128 / 156 )
#  82%|████████▏ | 128/156 [06:20<01:07,  2.42s/it]
#     .wave.shape: (1, 6679296) .score.shape: (1, 128, 13046) score_sample.shape: (13046,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2556.h5
# processing: id = 2557 ( 129 / 156 )
#  83%|████████▎ | 129/156 [06:27<01:43,  3.85s/it]
#     .wave.shape: (1, 33615360) .score.shape: (1, 128, 65655) score_sample.shape: (65655,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2557.h5
# processing: id = 2564 ( 130 / 156 )
#  83%|████████▎ | 130/156 [06:32<01:46,  4.11s/it]
#     .wave.shape: (1, 24428160) .score.shape: (1, 128, 47712) score_sample.shape: (47712,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2564.h5
# processing: id = 2566 ( 131 / 156 )
#  84%|████████▍ | 131/156 [06:35<01:38,  3.93s/it]
#     .wave.shape: (1, 17872128) .score.shape: (1, 128, 34907) score_sample.shape: (34907,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2566.h5
# processing: id = 2567 ( 132 / 156 )
#  85%|████████▍ | 132/156 [06:39<01:31,  3.80s/it]
#     .wave.shape: (1, 17073792) .score.shape: (1, 128, 33348) score_sample.shape: (33348,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2567.h5
# processing: id = 2568 ( 133 / 156 )
#  85%|████████▌ | 133/156 [06:43<01:29,  3.91s/it]
#     .wave.shape: (1, 21083904) .score.shape: (1, 128, 41180) score_sample.shape: (41180,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2568.h5
# processing: id = 2575 ( 134 / 156 )
#  86%|████████▌ | 134/156 [06:45<01:16,  3.46s/it]
#     .wave.shape: (1, 13401216) .score.shape: (1, 128, 26175) score_sample.shape: (26175,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2575.h5
# processing: id = 2576 ( 135 / 156 )
#  87%|████████▋ | 135/156 [06:48<01:06,  3.17s/it]
#     .wave.shape: (1, 12335616) .score.shape: (1, 128, 24093) score_sample.shape: (24093,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2576.h5
# processing: id = 2581 ( 136 / 156 )
#  87%|████████▋ | 136/156 [06:50<01:01,  3.08s/it]
#     .wave.shape: (1, 15246720) .score.shape: (1, 128, 29779) score_sample.shape: (29779,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2581.h5
# processing: id = 2582 ( 137 / 156 )
#  88%|████████▊ | 137/156 [06:54<00:59,  3.13s/it]
#     .wave.shape: (1, 17572608) .score.shape: (1, 128, 34322) score_sample.shape: (34322,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2582.h5
# processing: id = 2588 ( 138 / 156 )
#  88%|████████▊ | 138/156 [06:58<01:04,  3.61s/it]
#     .wave.shape: (1, 23058432) .score.shape: (1, 128, 45036) score_sample.shape: (45036,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2588.h5
# processing: id = 2590 ( 139 / 156 )
#  89%|████████▉ | 139/156 [07:02<01:01,  3.63s/it]
#     .wave.shape: (1, 17231616) .score.shape: (1, 128, 33656) score_sample.shape: (33656,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2590.h5
# processing: id = 2591 ( 140 / 156 )
#  90%|████████▉ | 140/156 [07:04<00:47,  2.99s/it]
#     .wave.shape: (1, 7915392) .score.shape: (1, 128, 15460) score_sample.shape: (15460,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2591.h5
# processing: id = 2593 ( 141 / 156 )
#  90%|█████████ | 141/156 [07:08<00:51,  3.44s/it]
#     .wave.shape: (1, 22618368) .score.shape: (1, 128, 44177) score_sample.shape: (44177,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2593.h5
# processing: id = 2594 ( 142 / 156 )
#  91%|█████████ | 142/156 [07:11<00:44,  3.20s/it]
#     .wave.shape: (1, 14082048) .score.shape: (1, 128, 27504) score_sample.shape: (27504,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2594.h5
# processing: id = 2595 ( 143 / 156 )
#  92%|█████████▏| 143/156 [07:13<00:39,  3.02s/it]
#     .wave.shape: (1, 13569408) .score.shape: (1, 128, 26503) score_sample.shape: (26503,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2595.h5
# processing: id = 2596 ( 144 / 156 )
#  92%|█████████▏| 144/156 [07:16<00:34,  2.91s/it]
#     .wave.shape: (1, 14367744) .score.shape: (1, 128, 28062) score_sample.shape: (28062,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2596.h5
# processing: id = 2603 ( 145 / 156 )
#  93%|█████████▎| 145/156 [07:20<00:35,  3.19s/it]
#     .wave.shape: (1, 18444672) .score.shape: (1, 128, 36025) score_sample.shape: (36025,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2603.h5
# processing: id = 2607 ( 146 / 156 )
#  94%|█████████▎| 146/156 [07:26<00:39,  3.94s/it]
#     .wave.shape: (1, 29722752) .score.shape: (1, 128, 58053) score_sample.shape: (58053,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2607.h5
# processing: id = 2608 ( 147 / 156 )
#  94%|█████████▍| 147/156 [07:29<00:33,  3.77s/it]
#     .wave.shape: (1, 17222400) .score.shape: (1, 128, 33638) score_sample.shape: (33638,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2608.h5
# processing: id = 2611 ( 148 / 156 )
#  95%|█████████▍| 148/156 [07:34<00:32,  4.06s/it]
#     .wave.shape: (1, 24839424) .score.shape: (1, 128, 48515) score_sample.shape: (48515,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2611.h5
# processing: id = 2614 ( 149 / 156 )
#  96%|█████████▌| 149/156 [07:39<00:31,  4.45s/it]
#     .wave.shape: (1, 28010880) .score.shape: (1, 128, 54709) score_sample.shape: (54709,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2614.h5
# processing: id = 2618 ( 150 / 156 )
#  96%|█████████▌| 150/156 [07:42<00:24,  4.04s/it]
#     .wave.shape: (1, 16060032) .score.shape: (1, 128, 31368) score_sample.shape: (31368,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2618.h5
# processing: id = 2619 ( 151 / 156 )
#  97%|█████████▋| 151/156 [07:44<00:17,  3.40s/it]
#     .wave.shape: (1, 10517760) .score.shape: (1, 128, 20543) score_sample.shape: (20543,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2619.h5
# processing: id = 2620 ( 152 / 156 )
#  97%|█████████▋| 152/156 [07:45<00:11,  2.78s/it]
#     .wave.shape: (1, 7050240) .score.shape: (1, 128, 13770) score_sample.shape: (13770,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2620.h5
# processing: id = 2632 ( 153 / 156 )
#  98%|█████████▊| 153/156 [07:48<00:08,  2.75s/it]
#     .wave.shape: (1, 15077376) .score.shape: (1, 128, 29448) score_sample.shape: (29448,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2632.h5
# processing: id = 2633 ( 154 / 156 )
#  99%|█████████▊| 154/156 [07:50<00:04,  2.46s/it]
#     .wave.shape: (1, 10010880) .score.shape: (1, 128, 19553) score_sample.shape: (19553,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2633.h5
# processing: id = 2677 ( 155 / 156 )
#  99%|█████████▉| 155/156 [07:54<00:02,  2.87s/it]
#     .wave.shape: (1, 19635840) .score.shape: (1, 128, 38352) score_sample.shape: (38352,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2677.h5
# processing: id = 2678 ( 156 / 156 )
# 100%|██████████| 156/156 [07:58<00:00,  3.20s/it]
#     .wave.shape: (1, 20831616) .score.shape: (1, 128, 40687) score_sample.shape: (40687,)
#     .wave.dtype: float32 .score.dtype: float32 score_sample.dtype: int64
#     saved: wsh5/2678.h5
# Done.

# %% [markdown]
# ## (2) MusicNet -> wsd 形式．

# %% [markdown]
# wsd 形式の中身は pickle

# %%
# mcn.data.musicnet_to_wsdata("/Users/yoshidayuuki/Downloads/musicnet/musicnet.npz", "/Users/yoshidayuuki/Downloads/musicnet/musicnet_metadata.csv", "wsdata", "Solo Piano")
# Out:
# processing: id = 1733 ( 1 / 156 )
#     .wave.shape: (24079104,) .score.shape: (128, 47030) score_sample.shape: (47030,)
#     .wave.dtype: float64 .score.dtype: float64 score_sample.dtype: int64

# %% [markdown]
# ## (3) wsd 形式 -> npz 形式（CQTの結果）

# %%
# mcn.data.make_cqt_inout("wsdata","thedata_raw.npz", mode='raw')
# Out:
# processing: wsdata = wsdata/1733.wsd
# (2, 84, 47030) (128, 47030)
# processing: wsdata = wsdata/1734.wsd
# (2, 84, 28047) (128, 28047)
# processing: wsdata = wsdata/1735.wsd
# (2, 84, 61578) (128, 61578)
# processing: wsdata = wsdata/1749.wsd
# (2, 84, 59981) (128, 59981)
# processing: wsdata = wsdata/1750.wsd
# (2, 84, 67543) (128, 67543)
# processing: wsdata = wsdata/1751.wsd
# (2, 84, 40971) (128, 40971)
# processing: wsdata = wsdata/1752.wsd
# (2, 84, 31242) (128, 31242)
# processing: wsdata = wsdata/1755.wsd
# (2, 84, 19794) (128, 19794)
# processing: wsdata = wsdata/1756.wsd
# (2, 84, 31998) (128, 31998)
# processing: wsdata = wsdata/1757.wsd
# (2, 84, 61207) (128, 61207)
# processing: wsdata = wsdata/1758.wsd
# (2, 84, 40345) (128, 40345)
# processing: wsdata = wsdata/1759.wsd
# (2, 84, 16767) (128, 16767)
# processing: wsdata = wsdata/1760.wsd
# (2, 84, 56466) (128, 56466)
# processing: wsdata = wsdata/1763.wsd
# (2, 84, 51708) (128, 51708)
# processing: wsdata = wsdata/1764.wsd
# (2, 84, 37749) (128, 37749)
# processing: wsdata = wsdata/1765.wsd
# (2, 84, 58278) (128, 58278)
# processing: wsdata = wsdata/1766.wsd
# (2, 84, 36810) (128, 36810)
# processing: wsdata = wsdata/1768.wsd
# (2, 84, 25054) (128, 25054)
# processing: wsdata = wsdata/1771.wsd
# (2, 84, 55760) (128, 55760)
# processing: wsdata = wsdata/1772.wsd
# (2, 84, 35958) (128, 35958)
# processing: wsdata = wsdata/1773.wsd
# (2, 84, 26476) (128, 26476)
# processing: wsdata = wsdata/1775.wsd
# (2, 84, 49804) (128, 49804)
# processing: wsdata = wsdata/1776.wsd
# (2, 84, 62541) (128, 62541)
# processing: wsdata = wsdata/1777.wsd
# (2, 84, 54221) (128, 54221)
# processing: wsdata = wsdata/2194.wsd
# (2, 84, 8622) (128, 8622)
# processing: wsdata = wsdata/2195.wsd
# (2, 84, 13361) (128, 13361)
# processing: wsdata = wsdata/2196.wsd
# (2, 84, 6501) (128, 6501)
# processing: wsdata = wsdata/2198.wsd
# (2, 84, 17049) (128, 17049)
# processing: wsdata = wsdata/2200.wsd
# (2, 84, 9779) (128, 9779)
# processing: wsdata = wsdata/2201.wsd
# (2, 84, 11565) (128, 11565)
# processing: wsdata = wsdata/2207.wsd
# (2, 84, 7720) (128, 7720)
# processing: wsdata = wsdata/2208.wsd
# (2, 84, 10404) (128, 10404)
# processing: wsdata = wsdata/2209.wsd
# (2, 84, 13849) (128, 13849)
# processing: wsdata = wsdata/2210.wsd
# (2, 84, 15361) (128, 15361)
# processing: wsdata = wsdata/2211.wsd
# (2, 84, 20433) (128, 20433)
# processing: wsdata = wsdata/2212.wsd
# (2, 84, 14904) (128, 14904)
# processing: wsdata = wsdata/2213.wsd
# (2, 84, 9990) (128, 9990)
# processing: wsdata = wsdata/2214.wsd
# (2, 84, 9246) (128, 9246)
# processing: wsdata = wsdata/2215.wsd
# (2, 84, 10029) (128, 10029)
# processing: wsdata = wsdata/2224.wsd
# (2, 84, 9372) (128, 9372)
# processing: wsdata = wsdata/2225.wsd
# (2, 84, 18405) (128, 18405)
# processing: wsdata = wsdata/2227.wsd
# (2, 84, 11149) (128, 11149)
# processing: wsdata = wsdata/2228.wsd
# (2, 84, 8449) (128, 8449)
# processing: wsdata = wsdata/2229.wsd
# (2, 84, 21067) (128, 21067)
# processing: wsdata = wsdata/2230.wsd
# (2, 84, 7286) (128, 7286)
# processing: wsdata = wsdata/2231.wsd
# (2, 84, 9961) (128, 9961)
# processing: wsdata = wsdata/2232.wsd
# (2, 84, 6768) (128, 6768)
# processing: wsdata = wsdata/2234.wsd
# (2, 84, 5517) (128, 5517)
# processing: wsdata = wsdata/2237.wsd
# (2, 84, 9405) (128, 9405)
# processing: wsdata = wsdata/2238.wsd
# (2, 84, 5169) (128, 5169)
# processing: wsdata = wsdata/2239.wsd
# (2, 84, 10339) (128, 10339)
# processing: wsdata = wsdata/2240.wsd
# (2, 84, 7974) (128, 7974)
# processing: wsdata = wsdata/2247.wsd
# (2, 84, 6998) (128, 6998)
# processing: wsdata = wsdata/2248.wsd
# (2, 84, 9014) (128, 9014)
# processing: wsdata = wsdata/2292.wsd
# (2, 84, 7866) (128, 7866)
# processing: wsdata = wsdata/2300.wsd
# (2, 84, 20516) (128, 20516)
# processing: wsdata = wsdata/2302.wsd
# (2, 84, 9331) (128, 9331)
# processing: wsdata = wsdata/2303.wsd
# (2, 84, 7981) (128, 7981)
# processing: wsdata = wsdata/2304.wsd
# (2, 84, 16914) (128, 16914)
# processing: wsdata = wsdata/2305.wsd
# (2, 84, 5612) (128, 5612)
# processing: wsdata = wsdata/2307.wsd
# (2, 84, 11817) (128, 11817)
# processing: wsdata = wsdata/2308.wsd
# (2, 84, 10494) (128, 10494)
# processing: wsdata = wsdata/2310.wsd
# (2, 84, 4759) (128, 4759)
# processing: wsdata = wsdata/2322.wsd
# (2, 84, 55641) (128, 55641)
# processing: wsdata = wsdata/2325.wsd
# (2, 84, 47489) (128, 47489)
# processing: wsdata = wsdata/2343.wsd
# (2, 84, 28672) (128, 28672)
# processing: wsdata = wsdata/2345.wsd
# (2, 84, 38158) (128, 38158)
# processing: wsdata = wsdata/2346.wsd
# (2, 84, 28933) (128, 28933)
# processing: wsdata = wsdata/2348.wsd
# (2, 84, 42525) (128, 42525)
# processing: wsdata = wsdata/2350.wsd
# (2, 84, 23794) (128, 23794)
# processing: wsdata = wsdata/2357.wsd
# (2, 84, 30807) (128, 30807)
# processing: wsdata = wsdata/2358.wsd
# (2, 84, 11880) (128, 11880)
# processing: wsdata = wsdata/2359.wsd
# (2, 84, 26251) (128, 26251)
# processing: wsdata = wsdata/2364.wsd
# (2, 84, 25581) (128, 25581)
# processing: wsdata = wsdata/2371.wsd
# (2, 84, 17681) (128, 17681)
# processing: wsdata = wsdata/2372.wsd
# (2, 84, 19688) (128, 19688)
# processing: wsdata = wsdata/2373.wsd
# (2, 84, 27444) (128, 27444)
# processing: wsdata = wsdata/2374.wsd
# (2, 84, 18651) (128, 18651)
# processing: wsdata = wsdata/2388.wsd
# (2, 84, 40800) (128, 40800)
# processing: wsdata = wsdata/2389.wsd
# (2, 84, 38732) (128, 38732)
# processing: wsdata = wsdata/2390.wsd
# (2, 84, 33773) (128, 33773)
# processing: wsdata = wsdata/2391.wsd
# (2, 84, 40775) (128, 40775)
# processing: wsdata = wsdata/2392.wsd
# (2, 84, 37690) (128, 37690)
# processing: wsdata = wsdata/2393.wsd
# (2, 84, 33003) (128, 33003)
# processing: wsdata = wsdata/2404.wsd
# (2, 84, 34378) (128, 34378)
# processing: wsdata = wsdata/2405.wsd
# (2, 84, 11885) (128, 11885)
# processing: wsdata = wsdata/2406.wsd
# (2, 84, 52718) (128, 52718)
# processing: wsdata = wsdata/2410.wsd
# (2, 84, 27000) (128, 27000)
# processing: wsdata = wsdata/2411.wsd
# (2, 84, 11118) (128, 11118)
# processing: wsdata = wsdata/2422.wsd
# (2, 84, 20806) (128, 20806)
# processing: wsdata = wsdata/2423.wsd
# (2, 84, 25644) (128, 25644)
# processing: wsdata = wsdata/2424.wsd
# (2, 84, 17465) (128, 17465)
# processing: wsdata = wsdata/2436.wsd
# (2, 84, 58948) (128, 58948)
# processing: wsdata = wsdata/2441.wsd
# (2, 84, 68468) (128, 68468)
# processing: wsdata = wsdata/2442.wsd
# (2, 84, 15078) (128, 15078)
# processing: wsdata = wsdata/2443.wsd
# (2, 84, 89159) (128, 89159)
# processing: wsdata = wsdata/2444.wsd
# (2, 84, 66380) (128, 66380)
# processing: wsdata = wsdata/2471.wsd
# (2, 84, 39065) (128, 39065)
# processing: wsdata = wsdata/2472.wsd
# (2, 84, 18554) (128, 18554)
# processing: wsdata = wsdata/2473.wsd
# (2, 84, 28879) (128, 28879)
# processing: wsdata = wsdata/2476.wsd
# (2, 84, 40865) (128, 40865)
# processing: wsdata = wsdata/2477.wsd
# (2, 84, 19024) (128, 19024)
# processing: wsdata = wsdata/2478.wsd
# (2, 84, 27498) (128, 27498)
# processing: wsdata = wsdata/2486.wsd
# (2, 84, 38601) (128, 38601)
# processing: wsdata = wsdata/2487.wsd
# (2, 84, 29259) (128, 29259)
# processing: wsdata = wsdata/2488.wsd
# (2, 84, 38010) (128, 38010)
# processing: wsdata = wsdata/2490.wsd
# (2, 84, 44719) (128, 44719)
# processing: wsdata = wsdata/2491.wsd
# (2, 84, 28517) (128, 28517)
# processing: wsdata = wsdata/2492.wsd
# (2, 84, 41405) (128, 41405)
# processing: wsdata = wsdata/2509.wsd
# (2, 84, 41720) (128, 41720)
# processing: wsdata = wsdata/2510.wsd
# (2, 84, 38941) (128, 38941)
# processing: wsdata = wsdata/2512.wsd
# (2, 84, 36480) (128, 36480)
# processing: wsdata = wsdata/2514.wsd
# (2, 84, 34965) (128, 34965)
# processing: wsdata = wsdata/2516.wsd
# (2, 84, 33413) (128, 33413)
# processing: wsdata = wsdata/2527.wsd
# (2, 84, 33258) (128, 33258)
# processing: wsdata = wsdata/2528.wsd
# (2, 84, 39942) (128, 39942)
# processing: wsdata = wsdata/2529.wsd
# (2, 84, 23731) (128, 23731)
# processing: wsdata = wsdata/2530.wsd
# (2, 84, 48411) (128, 48411)
# processing: wsdata = wsdata/2531.wsd
# (2, 84, 85453) (128, 85453)
# processing: wsdata = wsdata/2532.wsd
# (2, 84, 47237) (128, 47237)
# processing: wsdata = wsdata/2533.wsd
# (2, 84, 91987) (128, 91987)
# processing: wsdata = wsdata/2537.wsd
# (2, 84, 24714) (128, 24714)
# processing: wsdata = wsdata/2538.wsd
# (2, 84, 18275) (128, 18275)
# processing: wsdata = wsdata/2540.wsd
# (2, 84, 22698) (128, 22698)
# processing: wsdata = wsdata/2542.wsd
# (2, 84, 56073) (128, 56073)
# processing: wsdata = wsdata/2550.wsd
# (2, 84, 15530) (128, 15530)
# processing: wsdata = wsdata/2555.wsd
# (2, 84, 19269) (128, 19269)
# processing: wsdata = wsdata/2556.wsd
# (2, 84, 13046) (128, 13046)
# processing: wsdata = wsdata/2557.wsd
# (2, 84, 65655) (128, 65655)
# processing: wsdata = wsdata/2564.wsd
# (2, 84, 47712) (128, 47712)
# processing: wsdata = wsdata/2566.wsd
# (2, 84, 34907) (128, 34907)
# processing: wsdata = wsdata/2567.wsd
# (2, 84, 33348) (128, 33348)
# processing: wsdata = wsdata/2568.wsd
# (2, 84, 41180) (128, 41180)
# processing: wsdata = wsdata/2575.wsd
# (2, 84, 26175) (128, 26175)
# processing: wsdata = wsdata/2576.wsd
# (2, 84, 24093) (128, 24093)
# processing: wsdata = wsdata/2581.wsd
# (2, 84, 29779) (128, 29779)
# processing: wsdata = wsdata/2582.wsd
# (2, 84, 34322) (128, 34322)
# processing: wsdata = wsdata/2588.wsd
# (2, 84, 45036) (128, 45036)
# processing: wsdata = wsdata/2590.wsd
# (2, 84, 33656) (128, 33656)
# processing: wsdata = wsdata/2591.wsd
# (2, 84, 15460) (128, 15460)
# processing: wsdata = wsdata/2593.wsd
# (2, 84, 44177) (128, 44177)
# processing: wsdata = wsdata/2594.wsd
# (2, 84, 27504) (128, 27504)
# processing: wsdata = wsdata/2595.wsd
# (2, 84, 26503) (128, 26503)
# processing: wsdata = wsdata/2596.wsd
# (2, 84, 28062) (128, 28062)
# processing: wsdata = wsdata/2603.wsd
# (2, 84, 36025) (128, 36025)
# processing: wsdata = wsdata/2607.wsd
# (2, 84, 58053) (128, 58053)
# processing: wsdata = wsdata/2608.wsd
# (2, 84, 33638) (128, 33638)
# processing: wsdata = wsdata/2611.wsd
# (2, 84, 48515) (128, 48515)
# processing: wsdata = wsdata/2614.wsd
# (2, 84, 54709) (128, 54709)
# processing: wsdata = wsdata/2618.wsd
# (2, 84, 31368) (128, 31368)
# processing: wsdata = wsdata/2619.wsd
# (2, 84, 20543) (128, 20543)
# processing: wsdata = wsdata/2620.wsd
# (2, 84, 13770) (128, 13770)
# processing: wsdata = wsdata/2632.wsd
# (2, 84, 29448) (128, 29448)
# processing: wsdata = wsdata/2633.wsd
# (2, 84, 19553) (128, 19553)
# processing: wsdata = wsdata/2677.wsd
# (2, 84, 38352) (128, 38352)
# processing: wsdata = wsdata/2678.wsd
# (2, 84, 40687) (128, 40687)
# shape (2, 84, 4747088) (128, 4747088)

# %% [markdown]
# ## (4) MIDI files -> wsh5 形式．

# %% [markdown]
# wsh5 には，波形とスコア両方について，パートごとの情報を持たせる．これにより，データオーグメンテーションがとても捗る．

# %%
# ただし容量がやばすぎる！！！！！！！！   17パート，3分ある .mid ファイルが 1GB ほどの .h5 になった．（float32で3000秒ほど, 44100Hzなのでまあそんなもん．）
"""
for f in glob.glob('/Users/yoshidayuuki/Downloads/midiworld/midifile/[Aa]*/*.mid')[:3]:
    outfile = str(
        Path('/Users/yoshidayuuki/Downloads/midiworld/wsh5/')
        / Path(f).relative_to('/Users/yoshidayuuki/Downloads/midiworld/midifile')
    )[:-4] + '.h5'
    print(outfile)
    os.makedirs(os.path.dirname(outfile), exist_ok=True)
    mcn.data.midi_to_wsh5(f, outfile, sound_font='./mimicopynet/soundfonts/TimGM6mb.sf2')
"""
# Out:
# /Users/yoshidayuuki/Downloads/midiworld/wsh5/a/a.h5
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/pretty_midi-0.2.6-py3.5.egg/pretty_midi/pretty_midi.py:95: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/pretty_midi-0.2.6-py3.5.egg/pretty_midi/pretty_midi.py:95: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# /Users/yoshidayuuki/Downloads/midiworld/wsh5/A_Taste_of_Honey/Boogie_Oogie_Oogie.h5
# /Users/yoshidayuuki/Downloads/midiworld/wsh5/A_Teens/Mama_Mia.h5

# %% [markdown]
# # 生波形を入力にとるモデルを用いた学習

# %% [markdown]
# 以前は wsd 形式や wsh5 形式などを経由するデータフローしかなかったのですが，midiファイルから直接学習用データをモデルに渡せるようになりました．

# %%
# midiworld_path = '../midiworld/midifile'
midiworld_path = '../../../../../Downloads/midiworld/midifile'
soundfont_path = 'mimicopynet/soundfonts/TimGM6mb.sf2'

# %%
train_midis = mcn.data.MidiDataset(
    midis=glob.glob(midiworld_path + '/[Aa]*/*.mid'),
    size=10000,
    sf2_path=soundfont_path,
    length_sec=1.0, allow_drum=False, num_part=1, skip_silence=0.9,
    wave_sr=44100, score_sr=100
)
eval_midis = mcn.data.MidiDataset(
    midis=glob.glob(midiworld_path + '/[Bb]*/*.mid'),
    size=1000,
    sf2_path=soundfont_path,
    length_sec=1.0,  allow_drum=False, num_part=1, skip_silence=0.9,
    wave_sr=44100, score_sr=100
)
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]/Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/pretty_midi-0.2.6-py3.5.egg/pretty_midi/pretty_midi.py:95: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
# 100%|██████████| 248/248 [00:47<00:00,  3.85it/s]
#   0%|          | 0/444 [00:00<?, ?it/s]
# 248 MIDI files are successfully loaded.
#  22%|██▏       | 98/444 [00:19<00:41,  8.32it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Beastie_Boys/Girls.mid]
# [Error]
# <class 'KeyError'>
# (-1, 255)
#  37%|███▋      | 166/444 [00:33<00:45,  6.16it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Billy_Joel/Movin__Out.mid]
# [Error]
# <class 'OSError'>
# data byte must be in range 0..127
#  39%|███▊      | 172/444 [00:34<00:33,  8.05it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Billy_Joel/Pressure.mid]
# [Error]
# <class 'OSError'>
# data byte must be in range 0..127
#  66%|██████▌   | 292/444 [00:52<00:18,  8.31it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Bomfunk_MCs/B_Boys_And_Fly_Girls.mid]
# [Error]
# <class 'OSError'>
# MThd not found. Probably not a MIDI file
# [On loading ../../../../../Downloads/midiworld/midifile/Bomfunk_MCs/Uprocking_Beats.mid]
# [Error]
# <class 'OSError'>
# MThd not found. Probably not a MIDI file
#  81%|████████▏ | 361/444 [01:02<00:08,  9.71it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Brian_McKnight/On_The_Down_Low.mid]
# [Error]
# <class 'EOFError'>
#  93%|█████████▎| 411/444 [01:09<00:04,  7.01it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Bryan_Adams/On_A_Day_Like_Today.mid]
# [Error]
# <class 'IndexError'>
# list index out of range
#  98%|█████████▊| 436/444 [01:13<00:00,  8.10it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Bush/Glycerine.mid]
# [Error]
# <class 'KeyError'>
# (-1, 255)
#  99%|█████████▉| 441/444 [01:14<00:00,  5.71it/s]
# [On loading ../../../../../Downloads/midiworld/midifile/Busta_Rhymes/Woo_Hah.mid]
# [Error]
# <class 'OSError'>
# data byte must be in range 0..127
# 100%|██████████| 444/444 [01:15<00:00,  6.42it/s]
# 435 MIDI files are successfully loaded.

# %%
model = mcn.model.NoCQTModel()

# %%
# model.fit(train_midis, eval_midis=eval_midis) # gpu=-1
model.fit(train_midis, eval_midis=eval_midis, gpu=-1, bs_train=20, bs_eval=20, class_weight=np.array([1.0, 4.0]), result_dir='result') # gpu=-1
# Out:
# epoch       iteration   main/loss   main/precision  main/recall  main/fvalue  validation/main/loss  validation/main/precision  validation/main/recall  validation/main/fvalue  elapsed_time
# 0           10          0.71439     0.010809        0.401116     0.0210162                                                                                                     351.003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-d096dbec0e39> in <module>()
#       1 # model.fit(train_midis, eval_midis=eval_midis) # gpu=-1
# ----> 2 model.fit(train_midis, eval_midis=eval_midis, gpu=-1, bs_train=20, bs_eval=20, class_weight=np.array([1.0, 4.0]), result_dir='result') # gpu=-1
#
# /Users/yoshidayuuki/Documents/bitbucket/al4bb/sound/mimicopynet/mimicopynet/model/nocqt/model.py in fit(self, midis, eval_midis, **kwargs)
#     173         trn.extend(extensions.dump_graph('main/loss'))
#     174
# --> 175         trn.run()
#     176
#     177     def predict_proba(self, X):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/training/trainer.py in run(self, show_loop_exception_msg)
#     313                 self.observation = {}
#     314                 with reporter.scope(self.observation):
# --> 315                     update()
#     316                     for name, entry in extensions:
#     317                         if entry.trigger(self):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/training/updaters/standard_updater.py in update(self)
#     163
#     164         """
# --> 165         self.update_core()
#     166         self.iteration += 1
#     167
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/training/updaters/standard_updater.py in update_core(self)
#     175
#     176         if isinstance(in_arrays, tuple):
# --> 177             optimizer.update(loss_func, *in_arrays)
#     178         elif isinstance(in_arrays, dict):
#     179             optimizer.update(loss_func, **in_arrays)
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/optimizer.py in update(self, lossfun, *args, **kwds)
#     683             else:
#     684                 self.target.zerograds()
# --> 685             loss.backward(loss_scale=self._loss_scale)
#     686             del loss
#     687
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/variable.py in backward(self, retain_grad, enable_double_backprop, loss_scale)
#     979         """
#     980         with chainer.using_config('enable_backprop', enable_double_backprop):
# --> 981             self._backward_main(retain_grad, loss_scale)
#     982
#     983     def _backward_main(self, retain_grad, loss_scale):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/variable.py in _backward_main(self, retain_grad, loss_scale)
#    1059
#    1060                 _backprop_utils.backprop_step(
# -> 1061                     func, target_input_indexes, out_grad, in_grad)
#    1062
#    1063                 for hook in hooks:
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/_backprop_utils.py in backprop_step(func, target_input_indexes, grad_outputs, grad_inputs)
#     107     else:  # otherwise, backward should be overridden
#     108         gxs = func.backward(
# --> 109             target_input_indexes, grad_outputs)
#     110
#     111         if is_debug:
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/functions/connection/convolution_nd.py in backward(self, indexes, grad_outputs)
#     186             gx = chainer.functions.deconvolution_nd(
#     187                 gy, W, stride=self.stride, pad=self.pad, outsize=x_shape,
# --> 188                 dilate=self.dilate, groups=self.groups)
#     189             ret.append(gx)
#     190         if 1 in indexes:
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/functions/connection/deconvolution_nd.py in deconvolution_nd(x, W, b, stride, pad, outsize, dilate, groups)
#     375         ndim, stride, pad, outsize, dilate=dilate, groups=groups)
#     376     args = (x, W) if b is None else (x, W, b)
# --> 377     y, = func.apply(args)
#     378     return y
#     379
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/function_node.py in apply(self, inputs)
#     261                 outputs = static_forward_optimizations(self, in_data)
#     262             else:
# --> 263                 outputs = self.forward(in_data)
#     264
#     265         # Check for output array types
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/functions/connection/deconvolution_nd.py in forward(self, inputs)
#     184         xp = backend.get_array_module(*inputs)
#     185         if xp is numpy:
# --> 186             return self._forward_xp(x, W, b, numpy)
#     187         elif not self._use_cudnn(x, W):
#     188             return self._forward_xp(x, W, b, cuda.cupy)
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/functions/connection/deconvolution_nd.py in _forward_xp(self, x, W, b, xp)
#      81             return self._forward_grouped_convolution_xp(x, W, b, xp)
#      82         else:
# ---> 83             return self._forward_xp_core(x, W, b, xp)
#      84
#      85     def _forward_grouped_convolution_xp(self, x, W, b, xp):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/functions/connection/deconvolution_nd.py in _forward_xp_core(self, x, W, b, xp)
#     126
#     127         # gcol: C_O, k_1, ..., k_N, n, d_1, ..., d_N
# --> 128         gcol = xp.tensordot(W, x, (0, 1)).astype(x.dtype, copy=False)
#     129         # Roll n, which is batch size, before the first.
#     130         gcol = xp.rollaxis(gcol, ndim + 1)
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/numpy/core/numeric.py in tensordot(a, b, axes)
#    1391     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1392     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1393     res = dot(at, bt)
#    1394     return res.reshape(olda + oldb)
#    1395
#
# KeyboardInterrupt:

# %% [markdown]
# # BasicCNN を用いた学習．

# %% [markdown]
# BasicCNN は， CQT済みデータを入力に，ピアノロール(hold)を出力するモデルです．計算モデルだけでなく，学習用のデータをセットしたり，学習を行ったりするメソッドが付属しています．

# %%
model = mcn.model.BasicCNN(input_cnl=2)

# %%
model.load_cqt_inout("cqt_data/thedata_raw.npz")
# Out:
# [load_cqt_inout] train data loaded!
#     length of original data (in .npz): 4747088
#     number of data (== len(spect) == len(score)): 4746960
#     shape of each spect data: (2, 84, 128) float32
#     shape of each score data: (128, 128) int32
# [load_cqt_inout] dataset_train only is specified. (If you want to split it to training and test data,make the optional argument split_train_ratio (default: 1.0) lesser than 1.0.

# %%
sum_score = np.zeros(model.score[0].shape)
for s in model.score:
    sum_score += s

# %%
plt.imshow(sum_score/len(model.score), origin='lower'); plt.colorbar(); plt.show()

# %%
sum_attack = np.zeros(model.score[0].shape)
attack = np.zeros(model.score[0].shape)
for s in model.score:
    attack[:,1:] = np.logical_and(s[:,:-1]==0, s[:,1:]==1).astype(np.int32)
    sum_attack += attack
plt.imshow(sum_attack/len(model.score), origin='lower'); plt.colorbar(); plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e427954ec97b> in <module>()
#       2 attack = np.zeros(model.score[0].shape)
#       3 for s in model.score:
# ----> 4     attack[:,1:] = np.logical_and(s[:,:-1]==0, s[:,1:]==1).astype(np.int32)
#       5     sum_attack += attack
#       6 plt.imshow(sum_attack/len(model.score), origin='lower'); plt.colorbar(); plt.show()
#
# KeyboardInterrupt:

# %%
model.learn()
# Out:
# 37048 38
# iteration   main/accuracy  main/loss   validation/main/accuracy  validation/main/loss
#      total [..................................................]  0.00%
# this epoch [..................................................]  0.13%
#          5 iter, 0 epoch / 300000 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  0.00%
# this epoch [..................................................]  0.27%
#         10 iter, 0 epoch / 300000 iterations
#    0.19824 iters/sec. Estimated time to finish: 17 days, 12:21:20.477763.
#      total [..................................................]  0.01%
# this epoch [..................................................]  0.40%
#         15 iter, 0 epoch / 300000 iterations
#    0.19326 iters/sec. Estimated time to finish: 17 days, 23:11:01.972616.
#      total [..................................................]  0.01%
# this epoch [..................................................]  0.54%
#         20 iter, 0 epoch / 300000 iterations
#    0.19207 iters/sec. Estimated time to finish: 18 days, 1:51:00.666987.
#      total [..................................................]  0.01%
# this epoch [..................................................]  0.67%
#         25 iter, 0 epoch / 300000 iterations
#    0.19062 iters/sec. Estimated time to finish: 18 days, 5:07:20.833336.
#      total [..................................................]  0.01%
# this epoch [..................................................]  0.81%
#         30 iter, 0 epoch / 300000 iterations
#    0.19141 iters/sec. Estimated time to finish: 18 days, 3:19:33.070486.
#      total [..................................................]  0.01%
# this epoch [..................................................]  0.94%
#         35 iter, 0 epoch / 300000 iterations
#    0.19209 iters/sec. Estimated time to finish: 18 days, 1:46:59.330672.
#      total [..................................................]  0.01%
# this epoch [..................................................]  1.08%
#         40 iter, 0 epoch / 300000 iterations
#     0.1915 iters/sec. Estimated time to finish: 18 days, 3:06:44.027460.
#      total [..................................................]  0.01%
# this epoch [..................................................]  1.21%
#         45 iter, 0 epoch / 300000 iterations
#    0.19124 iters/sec. Estimated time to finish: 18 days, 3:41:30.904046.
# 50          nan            0.102901
#      total [..................................................]  0.02%
# this epoch [..................................................]  1.35%
#         50 iter, 0 epoch / 300000 iterations
#    0.19109 iters/sec. Estimated time to finish: 18 days, 4:01:23.421972.
#      total [..................................................]  0.02%
# this epoch [..................................................]  1.48%
#         55 iter, 0 epoch / 300000 iterations
#    0.19112 iters/sec. Estimated time to finish: 18 days, 3:56:12.451490.
#      total [..................................................]  0.02%
# this epoch [..................................................]  1.62%
#         60 iter, 0 epoch / 300000 iterations
#     0.1915 iters/sec. Estimated time to finish: 18 days, 3:04:05.429908.
#      total [..................................................]  0.02%
# this epoch [..................................................]  1.75%
#         65 iter, 0 epoch / 300000 iterations
#    0.19114 iters/sec. Estimated time to finish: 18 days, 3:53:26.886125.
#      total [..................................................]  0.02%
# this epoch [..................................................]  1.89%
#         70 iter, 0 epoch / 300000 iterations
#    0.19079 iters/sec. Estimated time to finish: 18 days, 4:41:09.990128.
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.02%
#         75 iter, 0 epoch / 300000 iterations
#    0.19045 iters/sec. Estimated time to finish: 18 days, 5:27:10.057840.
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.16%
#         80 iter, 0 epoch / 300000 iterations
#    0.19009 iters/sec. Estimated time to finish: 18 days, 6:15:48.598899.
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.29%
#         85 iter, 0 epoch / 300000 iterations
#    0.19079 iters/sec. Estimated time to finish: 18 days, 4:39:15.057613.
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.43%
#         90 iter, 0 epoch / 300000 iterations
#    0.19053 iters/sec. Estimated time to finish: 18 days, 5:14:40.521041.
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.56%
#         95 iter, 0 epoch / 300000 iterations
#     0.1903 iters/sec. Estimated time to finish: 18 days, 5:45:55.319161.
# 100         nan            0.0965746
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.70%
#        100 iter, 0 epoch / 300000 iterations
#    0.19009 iters/sec. Estimated time to finish: 18 days, 6:14:27.792423.
#      total [..................................................]  0.03%
# this epoch [#.................................................]  2.83%
#        105 iter, 0 epoch / 300000 iterations
#    0.18991 iters/sec. Estimated time to finish: 18 days, 6:39:33.628650.
#      total [..................................................]  0.04%
# this epoch [#.................................................]  2.97%
#        110 iter, 0 epoch / 300000 iterations
#    0.18964 iters/sec. Estimated time to finish: 18 days, 7:15:38.020412.
#      total [..................................................]  0.04%
# this epoch [#.................................................]  3.10%
#        115 iter, 0 epoch / 300000 iterations
#    0.18939 iters/sec. Estimated time to finish: 18 days, 7:50:04.168077.
#      total [..................................................]  0.04%
# this epoch [#.................................................]  3.24%
#        120 iter, 0 epoch / 300000 iterations
#    0.18931 iters/sec. Estimated time to finish: 18 days, 8:01:47.314453.
#      total [..................................................]  0.04%
# this epoch [#.................................................]  3.37%
#        125 iter, 0 epoch / 300000 iterations
#    0.18932 iters/sec. Estimated time to finish: 18 days, 7:58:57.376126.
#      total [..................................................]  0.04%
# this epoch [#.................................................]  3.51%
#        130 iter, 0 epoch / 300000 iterations
#    0.18924 iters/sec. Estimated time to finish: 18 days, 8:09:33.591296.
#      total [..................................................]  0.04%
# this epoch [#.................................................]  3.64%
#        135 iter, 0 epoch / 300000 iterations
#    0.18922 iters/sec. Estimated time to finish: 18 days, 8:12:51.065820.
#      total [..................................................]  0.05%
# this epoch [#.................................................]  3.78%
#        140 iter, 0 epoch / 300000 iterations
#     0.1892 iters/sec. Estimated time to finish: 18 days, 8:14:17.105694.
#      total [..................................................]  0.05%
# this epoch [#.................................................]  3.91%
#        145 iter, 0 epoch / 300000 iterations
#    0.18899 iters/sec. Estimated time to finish: 18 days, 8:44:04.059830.
# 150         nan            0.0932706
#      total [..................................................]  0.05%
# this epoch [##................................................]  4.05%
#        150 iter, 0 epoch / 300000 iterations
#    0.18868 iters/sec. Estimated time to finish: 18 days, 9:26:57.998820.
#      total [..................................................]  0.05%
# this epoch [##................................................]  4.18%
#        155 iter, 0 epoch / 300000 iterations
#    0.18842 iters/sec. Estimated time to finish: 18 days, 10:02:42.297155.
#      total [..................................................]  0.05%
# this epoch [##................................................]  4.32%
#        160 iter, 0 epoch / 300000 iterations
#    0.18818 iters/sec. Estimated time to finish: 18 days, 10:36:07.471965.
#      total [..................................................]  0.06%
# this epoch [##................................................]  4.45%
#        165 iter, 0 epoch / 300000 iterations
#    0.18797 iters/sec. Estimated time to finish: 18 days, 11:04:54.714526.
#      total [..................................................]  0.06%
# this epoch [##................................................]  4.59%
#        170 iter, 0 epoch / 300000 iterations
#    0.18784 iters/sec. Estimated time to finish: 18 days, 11:23:53.731039.
#      total [..................................................]  0.06%
# this epoch [##................................................]  4.72%
#        175 iter, 0 epoch / 300000 iterations
#    0.18761 iters/sec. Estimated time to finish: 18 days, 11:55:03.075435.
#      total [..................................................]  0.06%
# this epoch [##................................................]  4.86%
#        180 iter, 0 epoch / 300000 iterations
#    0.18742 iters/sec. Estimated time to finish: 18 days, 12:22:19.976436.
#      total [..................................................]  0.06%
# this epoch [##................................................]  4.99%
#        185 iter, 0 epoch / 300000 iterations
#    0.18737 iters/sec. Estimated time to finish: 18 days, 12:28:44.652513.
#      total [..................................................]  0.06%
# this epoch [##................................................]  5.13%
#        190 iter, 0 epoch / 300000 iterations
#     0.1873 iters/sec. Estimated time to finish: 18 days, 12:38:35.959704.
#      total [..................................................]  0.07%
# this epoch [##................................................]  5.26%
#        195 iter, 0 epoch / 300000 iterations
#    0.18708 iters/sec. Estimated time to finish: 18 days, 13:09:43.185386.
# 200         0.0640889      0.088159
#      total [..................................................]  0.07%
# this epoch [##................................................]  5.40%
#        200 iter, 0 epoch / 300000 iterations
#    0.18718 iters/sec. Estimated time to finish: 18 days, 12:54:36.684809.
#      total [..................................................]  0.07%
# this epoch [##................................................]  5.53%
#        205 iter, 0 epoch / 300000 iterations
#    0.18697 iters/sec. Estimated time to finish: 18 days, 13:23:32.582840.
#      total [..................................................]  0.07%
# this epoch [##................................................]  5.67%
#        210 iter, 0 epoch / 300000 iterations
#    0.18675 iters/sec. Estimated time to finish: 18 days, 13:54:22.462706.
#      total [..................................................]  0.07%
# this epoch [##................................................]  5.80%
#        215 iter, 0 epoch / 300000 iterations
#     0.1867 iters/sec. Estimated time to finish: 18 days, 14:02:05.990217.
#      total [..................................................]  0.07%
# this epoch [##................................................]  5.94%
#        220 iter, 0 epoch / 300000 iterations
#    0.18682 iters/sec. Estimated time to finish: 18 days, 13:44:32.934760.
#      total [..................................................]  0.07%
# this epoch [###...............................................]  6.07%
#        225 iter, 0 epoch / 300000 iterations
#    0.18674 iters/sec. Estimated time to finish: 18 days, 13:55:26.135241.
#      total [..................................................]  0.08%
# this epoch [###...............................................]  6.21%
#        230 iter, 0 epoch / 300000 iterations
#    0.18664 iters/sec. Estimated time to finish: 18 days, 14:09:36.169401.
#      total [..................................................]  0.08%
# this epoch [###...............................................]  6.34%
#        235 iter, 0 epoch / 300000 iterations
#    0.18646 iters/sec. Estimated time to finish: 18 days, 14:34:18.177348.
#      total [..................................................]  0.08%
# this epoch [###...............................................]  6.48%
#        240 iter, 0 epoch / 300000 iterations
#    0.18644 iters/sec. Estimated time to finish: 18 days, 14:36:59.475935.
#      total [..................................................]  0.08%
# this epoch [###...............................................]  6.61%
#        245 iter, 0 epoch / 300000 iterations
#    0.18629 iters/sec. Estimated time to finish: 18 days, 14:57:30.112236.
# 250         0.102257       0.0841144
#      total [..................................................]  0.08%
# this epoch [###...............................................]  6.75%
#        250 iter, 0 epoch / 300000 iterations
#    0.18618 iters/sec. Estimated time to finish: 18 days, 15:13:19.251548.
#      total [..................................................]  0.08%
# this epoch [###...............................................]  6.88%
#        255 iter, 0 epoch / 300000 iterations
#    0.18597 iters/sec. Estimated time to finish: 18 days, 15:43:15.759747.
#      total [..................................................]  0.09%
# this epoch [###...............................................]  7.02%
#        260 iter, 0 epoch / 300000 iterations
#    0.18581 iters/sec. Estimated time to finish: 18 days, 16:05:57.483306.
#      total [..................................................]  0.09%
# this epoch [###...............................................]  7.15%
#        265 iter, 0 epoch / 300000 iterations
#    0.18593 iters/sec. Estimated time to finish: 18 days, 15:47:44.616692.
#      total [..................................................]  0.09%
# this epoch [###...............................................]  7.29%
#        270 iter, 0 epoch / 300000 iterations
#    0.18589 iters/sec. Estimated time to finish: 18 days, 15:52:49.509665.
#      total [..................................................]  0.09%
# this epoch [###...............................................]  7.42%
#        275 iter, 0 epoch / 300000 iterations
#    0.18634 iters/sec. Estimated time to finish: 18 days, 14:48:37.915769.
#      total [..................................................]  0.09%
# this epoch [###...............................................]  7.56%
#        280 iter, 0 epoch / 300000 iterations
#    0.18633 iters/sec. Estimated time to finish: 18 days, 14:48:50.376323.
#      total [..................................................]  0.10%
# this epoch [###...............................................]  7.69%
#        285 iter, 0 epoch / 300000 iterations
#    0.18625 iters/sec. Estimated time to finish: 18 days, 14:59:43.850831.
#      total [..................................................]  0.10%
# this epoch [###...............................................]  7.83%
#        290 iter, 0 epoch / 300000 iterations
#    0.18614 iters/sec. Estimated time to finish: 18 days, 15:15:23.825020.
#      total [..................................................]  0.10%
# this epoch [###...............................................]  7.96%
#        295 iter, 0 epoch / 300000 iterations
#    0.18603 iters/sec. Estimated time to finish: 18 days, 15:31:01.679978.
# 300         0.183457       0.0785681
#      total [..................................................]  0.10%
# this epoch [####..............................................]  8.10%
#        300 iter, 0 epoch / 300000 iterations
#    0.18589 iters/sec. Estimated time to finish: 18 days, 15:50:14.093090.
#      total [..................................................]  0.10%
# this epoch [####..............................................]  8.23%
#        305 iter, 0 epoch / 300000 iterations
#    0.18578 iters/sec. Estimated time to finish: 18 days, 16:06:47.689362.
#      total [..................................................]  0.10%
# this epoch [####..............................................]  8.37%
#        310 iter, 0 epoch / 300000 iterations
#    0.18564 iters/sec. Estimated time to finish: 18 days, 16:26:22.766331.
#      total [..................................................]  0.10%
# this epoch [####..............................................]  8.50%
#        315 iter, 0 epoch / 300000 iterations
#    0.18552 iters/sec. Estimated time to finish: 18 days, 16:42:34.680940.
#      total [..................................................]  0.11%
# this epoch [####..............................................]  8.64%
#        320 iter, 0 epoch / 300000 iterations
#    0.18539 iters/sec. Estimated time to finish: 18 days, 17:00:56.791580.
#      total [..................................................]  0.11%
# this epoch [####..............................................]  8.77%
#        325 iter, 0 epoch / 300000 iterations
#    0.18525 iters/sec. Estimated time to finish: 18 days, 17:21:24.177836.
#      total [..................................................]  0.11%
# this epoch [####..............................................]  8.91%
#        330 iter, 0 epoch / 300000 iterations
#    0.18515 iters/sec. Estimated time to finish: 18 days, 17:35:15.805610.
#      total [..................................................]  0.11%
# this epoch [####..............................................]  9.04%
#        335 iter, 0 epoch / 300000 iterations
#     0.1851 iters/sec. Estimated time to finish: 18 days, 17:42:47.413883.
#      total [..................................................]  0.11%
# this epoch [####..............................................]  9.18%
#        340 iter, 0 epoch / 300000 iterations
#     0.1851 iters/sec. Estimated time to finish: 18 days, 17:42:27.909653.
#      total [..................................................]  0.11%
# this epoch [####..............................................]  9.31%
#        345 iter, 0 epoch / 300000 iterations
#     0.1851 iters/sec. Estimated time to finish: 18 days, 17:41:45.693554.
# 350         0.258705       0.0730339
#      total [..................................................]  0.12%
# this epoch [####..............................................]  9.45%
#        350 iter, 0 epoch / 300000 iterations
#    0.18501 iters/sec. Estimated time to finish: 18 days, 17:54:41.034535.
#      total [..................................................]  0.12%
# this epoch [####..............................................]  9.58%
#        355 iter, 0 epoch / 300000 iterations
#      0.185 iters/sec. Estimated time to finish: 18 days, 17:54:39.143783.
#      total [..................................................]  0.12%
# this epoch [####..............................................]  9.72%
#        360 iter, 0 epoch / 300000 iterations
#    0.18494 iters/sec. Estimated time to finish: 18 days, 18:03:45.961669.
#      total [..................................................]  0.12%
# this epoch [####..............................................]  9.85%
#        365 iter, 0 epoch / 300000 iterations
#    0.18485 iters/sec. Estimated time to finish: 18 days, 18:15:37.556903.
#      total [..................................................]  0.12%
# this epoch [####..............................................]  9.99%
#        370 iter, 0 epoch / 300000 iterations
#    0.18475 iters/sec. Estimated time to finish: 18 days, 18:29:35.638751.
#      total [..................................................]  0.12%
# this epoch [#####.............................................] 10.12%
#        375 iter, 0 epoch / 300000 iterations
#    0.18471 iters/sec. Estimated time to finish: 18 days, 18:35:51.478613.
#      total [..................................................]  0.13%
# this epoch [#####.............................................] 10.26%
#        380 iter, 0 epoch / 300000 iterations
#    0.18474 iters/sec. Estimated time to finish: 18 days, 18:30:46.407729.
#      total [..................................................]  0.13%
# this epoch [#####.............................................] 10.39%
#        385 iter, 0 epoch / 300000 iterations
#    0.18463 iters/sec. Estimated time to finish: 18 days, 18:46:57.881479.
#      total [..................................................]  0.13%
# this epoch [#####.............................................] 10.53%
#        390 iter, 0 epoch / 300000 iterations
#    0.18455 iters/sec. Estimated time to finish: 18 days, 18:57:19.999051.
#      total [..................................................]  0.13%
# this epoch [#####.............................................] 10.66%
#        395 iter, 0 epoch / 300000 iterations
#    0.18446 iters/sec. Estimated time to finish: 18 days, 19:10:47.161475.
# 400         0.309827       0.0698854
#      total [..................................................]  0.13%
# this epoch [#####.............................................] 10.80%
#        400 iter, 0 epoch / 300000 iterations
#    0.18439 iters/sec. Estimated time to finish: 18 days, 19:20:33.967128.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 10.93%
#        405 iter, 0 epoch / 300000 iterations
#    0.18434 iters/sec. Estimated time to finish: 18 days, 19:26:49.175848.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 11.07%
#        410 iter, 0 epoch / 300000 iterations
#    0.18421 iters/sec. Estimated time to finish: 18 days, 19:45:50.729199.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 11.20%
#        415 iter, 0 epoch / 300000 iterations
#    0.18414 iters/sec. Estimated time to finish: 18 days, 19:56:22.063947.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 11.34%
#        420 iter, 0 epoch / 300000 iterations
#    0.18409 iters/sec. Estimated time to finish: 18 days, 20:02:25.229033.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 11.47%
#        425 iter, 0 epoch / 300000 iterations
#    0.18406 iters/sec. Estimated time to finish: 18 days, 20:06:29.975666.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 11.61%
#        430 iter, 0 epoch / 300000 iterations
#    0.18407 iters/sec. Estimated time to finish: 18 days, 20:05:17.077711.
#      total [..................................................]  0.14%
# this epoch [#####.............................................] 11.74%
#        435 iter, 0 epoch / 300000 iterations
#    0.18402 iters/sec. Estimated time to finish: 18 days, 20:11:38.559212.
#      total [..................................................]  0.15%
# this epoch [#####.............................................] 11.88%
#        440 iter, 0 epoch / 300000 iterations
#      0.184 iters/sec. Estimated time to finish: 18 days, 20:13:58.117913.
#      total [..................................................]  0.15%
# this epoch [######............................................] 12.01%
#        445 iter, 0 epoch / 300000 iterations
#    0.18396 iters/sec. Estimated time to finish: 18 days, 20:20:13.139970.
# 450         0.354366       0.0678461
#      total [..................................................]  0.15%
# this epoch [######............................................] 12.15%
#        450 iter, 0 epoch / 300000 iterations
#    0.18383 iters/sec. Estimated time to finish: 18 days, 20:38:44.173478.
#      total [..................................................]  0.15%
# this epoch [######............................................] 12.28%
#        455 iter, 0 epoch / 300000 iterations
#    0.18378 iters/sec. Estimated time to finish: 18 days, 20:45:13.326445.
#      total [..................................................]  0.15%
# this epoch [######............................................] 12.42%
#        460 iter, 0 epoch / 300000 iterations
#    0.18377 iters/sec. Estimated time to finish: 18 days, 20:46:31.460451.
#      total [..................................................]  0.15%
# this epoch [######............................................] 12.55%
#        465 iter, 0 epoch / 300000 iterations
#    0.18373 iters/sec. Estimated time to finish: 18 days, 20:51:08.887303.
#      total [..................................................]  0.16%
# this epoch [######............................................] 12.69%
#        470 iter, 0 epoch / 300000 iterations
#    0.18367 iters/sec. Estimated time to finish: 18 days, 21:00:16.735734.
#      total [..................................................]  0.16%
# this epoch [######............................................] 12.82%
#        475 iter, 0 epoch / 300000 iterations
#    0.18366 iters/sec. Estimated time to finish: 18 days, 21:01:51.057408.
#      total [..................................................]  0.16%
# this epoch [######............................................] 12.96%
#        480 iter, 0 epoch / 300000 iterations
#    0.18354 iters/sec. Estimated time to finish: 18 days, 21:18:20.138911.
#      total [..................................................]  0.16%
# this epoch [######............................................] 13.09%
#        485 iter, 0 epoch / 300000 iterations
#    0.18352 iters/sec. Estimated time to finish: 18 days, 21:21:12.304271.
#      total [..................................................]  0.16%
# this epoch [######............................................] 13.23%
#        490 iter, 0 epoch / 300000 iterations
#    0.18363 iters/sec. Estimated time to finish: 18 days, 21:04:38.861017.
#      total [..................................................]  0.17%
# this epoch [######............................................] 13.36%
#        495 iter, 0 epoch / 300000 iterations
#    0.18366 iters/sec. Estimated time to finish: 18 days, 20:59:59.314901.
# 500         0.359829       0.0641936   0.360723                  0.0632115
#      total [..................................................]  0.17%
# this epoch [######............................................] 13.50%
#        500 iter, 0 epoch / 300000 iterations
#    0.18314 iters/sec. Estimated time to finish: 18 days, 22:15:40.243263.
#      total [..................................................]  0.17%
# this epoch [######............................................] 13.63%
#        505 iter, 0 epoch / 300000 iterations
#    0.18312 iters/sec. Estimated time to finish: 18 days, 22:17:57.479493.
#      total [..................................................]  0.17%
# this epoch [######............................................] 13.77%
#        510 iter, 0 epoch / 300000 iterations
#     0.1831 iters/sec. Estimated time to finish: 18 days, 22:20:29.918670.
#      total [..................................................]  0.17%
# this epoch [######............................................] 13.90%
#        515 iter, 0 epoch / 300000 iterations
#    0.18323 iters/sec. Estimated time to finish: 18 days, 22:01:31.999216.
#      total [..................................................]  0.17%
# this epoch [#######...........................................] 14.04%
#        520 iter, 0 epoch / 300000 iterations
#    0.18311 iters/sec. Estimated time to finish: 18 days, 22:18:29.478556.
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.17%
#        525 iter, 0 epoch / 300000 iterations
#    0.18307 iters/sec. Estimated time to finish: 18 days, 22:23:46.885174.
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.31%
#        530 iter, 0 epoch / 300000 iterations
#    0.18294 iters/sec. Estimated time to finish: 18 days, 22:43:00.683922.
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.44%
#        535 iter, 0 epoch / 300000 iterations
#    0.18278 iters/sec. Estimated time to finish: 18 days, 23:05:49.624295.
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.58%
#        540 iter, 0 epoch / 300000 iterations
#    0.18266 iters/sec. Estimated time to finish: 18 days, 23:23:56.318368.
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.71%
#        545 iter, 0 epoch / 300000 iterations
#    0.18259 iters/sec. Estimated time to finish: 18 days, 23:34:09.262627.
# 550         0.379722       0.0629599
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.85%
#        550 iter, 0 epoch / 300000 iterations
#    0.18245 iters/sec. Estimated time to finish: 18 days, 23:54:06.521466.
#      total [..................................................]  0.18%
# this epoch [#######...........................................] 14.98%
#        555 iter, 0 epoch / 300000 iterations
#    0.18238 iters/sec. Estimated time to finish: 19 days, 0:05:15.844713.
#      total [..................................................]  0.19%
# this epoch [#######...........................................] 15.12%
#        560 iter, 0 epoch / 300000 iterations
#    0.18223 iters/sec. Estimated time to finish: 19 days, 0:26:30.026909.
#      total [..................................................]  0.19%
# this epoch [#######...........................................] 15.25%
#        565 iter, 0 epoch / 300000 iterations
#    0.18226 iters/sec. Estimated time to finish: 19 days, 0:22:03.429215.
#      total [..................................................]  0.19%
# this epoch [#######...........................................] 15.39%
#        570 iter, 0 epoch / 300000 iterations
#    0.18215 iters/sec. Estimated time to finish: 19 days, 0:37:53.732062.
#      total [..................................................]  0.19%
# this epoch [#######...........................................] 15.52%
#        575 iter, 0 epoch / 300000 iterations
#    0.18214 iters/sec. Estimated time to finish: 19 days, 0:38:48.861068.
#      total [..................................................]  0.19%
# this epoch [#######...........................................] 15.66%
#        580 iter, 0 epoch / 300000 iterations
#    0.18212 iters/sec. Estimated time to finish: 19 days, 0:41:46.039166.
#      total [..................................................]  0.19%
# this epoch [#######...........................................] 15.79%
#        585 iter, 0 epoch / 300000 iterations
#    0.18186 iters/sec. Estimated time to finish: 19 days, 1:20:12.565528.
#      total [..................................................]  0.20%
# this epoch [#######...........................................] 15.93%
#        590 iter, 0 epoch / 300000 iterations
#    0.18183 iters/sec. Estimated time to finish: 19 days, 1:23:30.574770.
#      total [..................................................]  0.20%
# this epoch [########..........................................] 16.06%
#        595 iter, 0 epoch / 300000 iterations
#    0.18176 iters/sec. Estimated time to finish: 19 days, 1:33:52.976507.
# 600         0.417795       0.0596051
#      total [..................................................]  0.20%
# this epoch [########..........................................] 16.20%
#        600 iter, 0 epoch / 300000 iterations
#    0.18179 iters/sec. Estimated time to finish: 19 days, 1:28:37.557225.
#      total [..................................................]  0.20%
# this epoch [########..........................................] 16.33%
#        605 iter, 0 epoch / 300000 iterations
#    0.18174 iters/sec. Estimated time to finish: 19 days, 1:36:32.254516.
#      total [..................................................]  0.20%
# this epoch [########..........................................] 16.47%
#        610 iter, 0 epoch / 300000 iterations
#    0.18181 iters/sec. Estimated time to finish: 19 days, 1:24:35.656342.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 16.60%
#        615 iter, 0 epoch / 300000 iterations
#    0.18177 iters/sec. Estimated time to finish: 19 days, 1:31:26.000425.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 16.74%
#        620 iter, 0 epoch / 300000 iterations
#    0.18155 iters/sec. Estimated time to finish: 19 days, 2:03:23.493862.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 16.87%
#        625 iter, 0 epoch / 300000 iterations
#    0.18153 iters/sec. Estimated time to finish: 19 days, 2:06:56.657448.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 17.00%
#        630 iter, 0 epoch / 300000 iterations
#    0.18159 iters/sec. Estimated time to finish: 19 days, 1:56:05.984727.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 17.14%
#        635 iter, 0 epoch / 300000 iterations
#    0.18152 iters/sec. Estimated time to finish: 19 days, 2:06:48.415376.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 17.27%
#        640 iter, 0 epoch / 300000 iterations
#    0.18148 iters/sec. Estimated time to finish: 19 days, 2:12:07.645338.
#      total [..................................................]  0.21%
# this epoch [########..........................................] 17.41%
#        645 iter, 0 epoch / 300000 iterations
#    0.18187 iters/sec. Estimated time to finish: 19 days, 1:13:39.560127.
# 650         0.430508       0.0621132
#      total [..................................................]  0.22%
# this epoch [########..........................................] 17.54%
#        650 iter, 0 epoch / 300000 iterations
#    0.18191 iters/sec. Estimated time to finish: 19 days, 1:06:40.421324.
#      total [..................................................]  0.22%
# this epoch [########..........................................] 17.68%
#        655 iter, 0 epoch / 300000 iterations
#    0.18196 iters/sec. Estimated time to finish: 19 days, 0:58:25.549109.
#      total [..................................................]  0.22%
# this epoch [########..........................................] 17.81%
#        660 iter, 0 epoch / 300000 iterations
#    0.18193 iters/sec. Estimated time to finish: 19 days, 1:02:04.019126.
#      total [..................................................]  0.22%
# this epoch [########..........................................] 17.95%
#        665 iter, 0 epoch / 300000 iterations
#    0.18193 iters/sec. Estimated time to finish: 19 days, 1:01:36.733000.
#      total [..................................................]  0.22%
# this epoch [#########.........................................] 18.08%
#        670 iter, 0 epoch / 300000 iterations
#    0.18188 iters/sec. Estimated time to finish: 19 days, 1:09:46.878275.
#      total [..................................................]  0.22%
# this epoch [#########.........................................] 18.22%
#        675 iter, 0 epoch / 300000 iterations
#    0.18197 iters/sec. Estimated time to finish: 19 days, 0:55:32.253350.
#      total [..................................................]  0.23%
# this epoch [#########.........................................] 18.35%
#        680 iter, 0 epoch / 300000 iterations
#    0.18201 iters/sec. Estimated time to finish: 19 days, 0:48:34.132896.
#      total [..................................................]  0.23%
# this epoch [#########.........................................] 18.49%
#        685 iter, 0 epoch / 300000 iterations
#      0.182 iters/sec. Estimated time to finish: 19 days, 0:49:17.139425.
#      total [..................................................]  0.23%
# this epoch [#########.........................................] 18.62%
#        690 iter, 0 epoch / 300000 iterations
#    0.18215 iters/sec. Estimated time to finish: 19 days, 0:26:13.926066.
#      total [..................................................]  0.23%
# this epoch [#########.........................................] 18.76%
#        695 iter, 0 epoch / 300000 iterations
#    0.18236 iters/sec. Estimated time to finish: 18 days, 23:55:06.337500.
# 700         0.419864       0.0629869
#      total [..................................................]  0.23%
# this epoch [#########.........................................] 18.89%
#        700 iter, 0 epoch / 300000 iterations
#    0.18232 iters/sec. Estimated time to finish: 19 days, 0:00:28.078041.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.03%
#        705 iter, 0 epoch / 300000 iterations
#    0.18241 iters/sec. Estimated time to finish: 18 days, 23:45:46.352024.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.16%
#        710 iter, 0 epoch / 300000 iterations
#    0.18262 iters/sec. Estimated time to finish: 18 days, 23:15:11.120645.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.30%
#        715 iter, 0 epoch / 300000 iterations
#    0.18267 iters/sec. Estimated time to finish: 18 days, 23:06:47.878036.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.43%
#        720 iter, 0 epoch / 300000 iterations
#    0.18264 iters/sec. Estimated time to finish: 18 days, 23:10:48.438230.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.57%
#        725 iter, 0 epoch / 300000 iterations
#    0.18269 iters/sec. Estimated time to finish: 18 days, 23:02:59.713178.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.70%
#        730 iter, 0 epoch / 300000 iterations
#    0.18273 iters/sec. Estimated time to finish: 18 days, 22:56:17.472387.
#      total [..................................................]  0.24%
# this epoch [#########.........................................] 19.84%
#        735 iter, 0 epoch / 300000 iterations
#    0.18304 iters/sec. Estimated time to finish: 18 days, 22:09:56.903250.
#      total [..................................................]  0.25%
# this epoch [#########.........................................] 19.97%
#        740 iter, 0 epoch / 300000 iterations
#    0.18344 iters/sec. Estimated time to finish: 18 days, 21:09:08.655847.
#      total [..................................................]  0.25%
# this epoch [##########........................................] 20.11%
#        745 iter, 0 epoch / 300000 iterations
#     0.1837 iters/sec. Estimated time to finish: 18 days, 20:31:20.483448.
# 750         0.4254         0.0610959
#      total [..................................................]  0.25%
# this epoch [##########........................................] 20.24%
#        750 iter, 0 epoch / 300000 iterations
#    0.18376 iters/sec. Estimated time to finish: 18 days, 20:21:13.275572.
#      total [..................................................]  0.25%
# this epoch [##########........................................] 20.38%
#        755 iter, 0 epoch / 300000 iterations
#    0.18388 iters/sec. Estimated time to finish: 18 days, 20:03:14.714475.
#      total [..................................................]  0.25%
# this epoch [##########........................................] 20.51%
#        760 iter, 0 epoch / 300000 iterations
#    0.18399 iters/sec. Estimated time to finish: 18 days, 19:47:15.177802.
#      total [..................................................]  0.26%
# this epoch [##########........................................] 20.65%
#        765 iter, 0 epoch / 300000 iterations
#    0.18391 iters/sec. Estimated time to finish: 18 days, 19:58:33.246480.
#      total [..................................................]  0.26%
# this epoch [##########........................................] 20.78%
#        770 iter, 0 epoch / 300000 iterations
#    0.18392 iters/sec. Estimated time to finish: 18 days, 19:55:21.436523.
#      total [..................................................]  0.26%
# this epoch [##########........................................] 20.92%
#        775 iter, 0 epoch / 300000 iterations
#    0.18368 iters/sec. Estimated time to finish: 18 days, 20:30:57.565534.
#      total [..................................................]  0.26%
# this epoch [##########........................................] 21.05%
#        780 iter, 0 epoch / 300000 iterations
#    0.18369 iters/sec. Estimated time to finish: 18 days, 20:28:27.249330.
#      total [..................................................]  0.26%
# this epoch [##########........................................] 21.19%
#        785 iter, 0 epoch / 300000 iterations
#    0.18376 iters/sec. Estimated time to finish: 18 days, 20:17:42.930415.
#      total [..................................................]  0.26%
# this epoch [##########........................................] 21.32%
#        790 iter, 0 epoch / 300000 iterations
#    0.18385 iters/sec. Estimated time to finish: 18 days, 20:05:10.508862.
#      total [..................................................]  0.27%
# this epoch [##########........................................] 21.46%
#        795 iter, 0 epoch / 300000 iterations
#     0.1839 iters/sec. Estimated time to finish: 18 days, 19:56:42.154535.
# 800         0.442864       0.0605451
#      total [..................................................]  0.27%
# this epoch [##########........................................] 21.59%
#        800 iter, 0 epoch / 300000 iterations
#    0.18398 iters/sec. Estimated time to finish: 18 days, 19:44:15.025341.
#      total [..................................................]  0.27%
# this epoch [##########........................................] 21.73%
#        805 iter, 0 epoch / 300000 iterations
#    0.18404 iters/sec. Estimated time to finish: 18 days, 19:34:52.876514.
#      total [..................................................]  0.27%
# this epoch [##########........................................] 21.86%
#        810 iter, 0 epoch / 300000 iterations
#    0.18413 iters/sec. Estimated time to finish: 18 days, 19:22:03.933093.
#      total [..................................................]  0.27%
# this epoch [##########........................................] 22.00%
#        815 iter, 0 epoch / 300000 iterations
#    0.18421 iters/sec. Estimated time to finish: 18 days, 19:08:48.262817.
#      total [..................................................]  0.27%
# this epoch [###########.......................................] 22.13%
#        820 iter, 0 epoch / 300000 iterations
#    0.18425 iters/sec. Estimated time to finish: 18 days, 19:02:32.858767.
#      total [..................................................]  0.27%
# this epoch [###########.......................................] 22.27%
#        825 iter, 0 epoch / 300000 iterations
#    0.18437 iters/sec. Estimated time to finish: 18 days, 18:44:07.921865.
#      total [..................................................]  0.28%
# this epoch [###########.......................................] 22.40%
#        830 iter, 0 epoch / 300000 iterations
#    0.18446 iters/sec. Estimated time to finish: 18 days, 18:31:15.756799.
#      total [..................................................]  0.28%
# this epoch [###########.......................................] 22.54%
#        835 iter, 0 epoch / 300000 iterations
#    0.18452 iters/sec. Estimated time to finish: 18 days, 18:21:28.815880.
#      total [..................................................]  0.28%
# this epoch [###########.......................................] 22.67%
#        840 iter, 0 epoch / 300000 iterations
#    0.18454 iters/sec. Estimated time to finish: 18 days, 18:18:27.819092.
#      total [..................................................]  0.28%
# this epoch [###########.......................................] 22.81%
#        845 iter, 0 epoch / 300000 iterations
#    0.18458 iters/sec. Estimated time to finish: 18 days, 18:12:57.331970.
# 850         0.453192       0.0580237
#      total [..................................................]  0.28%
# this epoch [###########.......................................] 22.94%
#        850 iter, 0 epoch / 300000 iterations
#    0.18485 iters/sec. Estimated time to finish: 18 days, 17:32:48.944084.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.08%
#        855 iter, 0 epoch / 300000 iterations
#    0.18484 iters/sec. Estimated time to finish: 18 days, 17:33:34.594717.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.21%
#        860 iter, 0 epoch / 300000 iterations
#    0.18491 iters/sec. Estimated time to finish: 18 days, 17:22:44.975553.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.35%
#        865 iter, 0 epoch / 300000 iterations
#    0.18499 iters/sec. Estimated time to finish: 18 days, 17:10:34.718021.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.48%
#        870 iter, 0 epoch / 300000 iterations
#    0.18507 iters/sec. Estimated time to finish: 18 days, 16:58:08.549811.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.62%
#        875 iter, 0 epoch / 300000 iterations
#    0.18513 iters/sec. Estimated time to finish: 18 days, 16:49:29.312951.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.75%
#        880 iter, 0 epoch / 300000 iterations
#    0.18512 iters/sec. Estimated time to finish: 18 days, 16:50:27.536585.
#      total [..................................................]  0.29%
# this epoch [###########.......................................] 23.89%
#        885 iter, 0 epoch / 300000 iterations
#    0.18523 iters/sec. Estimated time to finish: 18 days, 16:33:34.731858.
#      total [..................................................]  0.30%
# this epoch [############......................................] 24.02%
#        890 iter, 0 epoch / 300000 iterations
#     0.1853 iters/sec. Estimated time to finish: 18 days, 16:23:51.258799.
# ...
#    0.18823 iters/sec. Estimated time to finish: 18 days, 2:02:15.665980.
#      total [..................................................]  1.97%
# this epoch [#############################.....................] 59.12%
#       5895 iter, 1 epoch / 300000 iterations
#    0.18822 iters/sec. Estimated time to finish: 18 days, 2:02:47.286717.
# 5900        0.560931       0.0471991
#      total [..................................................]  1.97%
# this epoch [#############################.....................] 59.25%
#       5900 iter, 1 epoch / 300000 iterations
#     0.1882 iters/sec. Estimated time to finish: 18 days, 2:05:01.444696.
#      total [..................................................]  1.97%
# this epoch [#############################.....................] 59.39%
#       5905 iter, 1 epoch / 300000 iterations
#    0.18834 iters/sec. Estimated time to finish: 18 days, 1:45:45.348150.
#      total [..................................................]  1.97%
# this epoch [#############################.....................] 59.52%
#       5910 iter, 1 epoch / 300000 iterations
#    0.18837 iters/sec. Estimated time to finish: 18 days, 1:40:59.399562.
#      total [..................................................]  1.97%
# this epoch [#############################.....................] 59.66%
#       5915 iter, 1 epoch / 300000 iterations
#    0.18834 iters/sec. Estimated time to finish: 18 days, 1:44:48.083164.
#      total [..................................................]  1.97%
# this epoch [#############################.....................] 59.79%
#       5920 iter, 1 epoch / 300000 iterations
#    0.18821 iters/sec. Estimated time to finish: 18 days, 2:01:21.464919.
#      total [..................................................]  1.98%
# this epoch [#############################.....................] 59.93%
#       5925 iter, 1 epoch / 300000 iterations
#    0.18823 iters/sec. Estimated time to finish: 18 days, 1:58:41.205869.
#      total [..................................................]  1.98%
# this epoch [##############################....................] 60.06%
#       5930 iter, 1 epoch / 300000 iterations
#    0.18817 iters/sec. Estimated time to finish: 18 days, 2:06:59.891615.
#      total [..................................................]  1.98%
# this epoch [##############################....................] 60.20%
#       5935 iter, 1 epoch / 300000 iterations
#    0.18813 iters/sec. Estimated time to finish: 18 days, 2:11:30.841944.
#      total [..................................................]  1.98%
# this epoch [##############################....................] 60.33%
#       5940 iter, 1 epoch / 300000 iterations
#    0.18817 iters/sec. Estimated time to finish: 18 days, 2:04:59.944961.
#      total [..................................................]  1.98%
# this epoch [##############################....................] 60.47%
#       5945 iter, 1 epoch / 300000 iterations
#    0.18816 iters/sec. Estimated time to finish: 18 days, 2:05:54.676482.
# 5950        0.578103       0.0463712
#      total [..................................................]  1.98%
# this epoch [##############################....................] 60.60%
#       5950 iter, 1 epoch / 300000 iterations
#    0.18829 iters/sec. Estimated time to finish: 18 days, 1:48:15.080399.
#      total [..................................................]  1.98%
# this epoch [##############################....................] 60.74%
#       5955 iter, 1 epoch / 300000 iterations
#    0.18827 iters/sec. Estimated time to finish: 18 days, 1:49:56.615065.
#      total [..................................................]  1.99%
# this epoch [##############################....................] 60.87%
#       5960 iter, 1 epoch / 300000 iterations
#    0.18816 iters/sec. Estimated time to finish: 18 days, 2:04:46.557679.
#      total [..................................................]  1.99%
# this epoch [##############################....................] 61.01%
#       5965 iter, 1 epoch / 300000 iterations
#    0.18814 iters/sec. Estimated time to finish: 18 days, 2:08:06.036092.
#      total [..................................................]  1.99%
# this epoch [##############################....................] 61.14%
#       5970 iter, 1 epoch / 300000 iterations
#    0.18798 iters/sec. Estimated time to finish: 18 days, 2:29:30.416405.
#      total [..................................................]  1.99%
# this epoch [##############################....................] 61.28%
#       5975 iter, 1 epoch / 300000 iterations
#    0.18781 iters/sec. Estimated time to finish: 18 days, 2:52:08.406014.
#      total [..................................................]  1.99%
# this epoch [##############################....................] 61.41%
#       5980 iter, 1 epoch / 300000 iterations
#    0.18775 iters/sec. Estimated time to finish: 18 days, 2:59:40.340047.
#      total [..................................................]  1.99%
# this epoch [##############################....................] 61.55%
#       5985 iter, 1 epoch / 300000 iterations
#    0.18747 iters/sec. Estimated time to finish: 18 days, 3:39:26.821104.
#      total [..................................................]  2.00%
# this epoch [##############################....................] 61.68%
#       5990 iter, 1 epoch / 300000 iterations
#    0.18757 iters/sec. Estimated time to finish: 18 days, 3:23:46.733568.
#      total [..................................................]  2.00%
# this epoch [##############################....................] 61.82%
#       5995 iter, 1 epoch / 300000 iterations
#    0.18743 iters/sec. Estimated time to finish: 18 days, 3:44:07.641300.
# 6000        0.579656       0.0457164   0.567117                  0.0464384
#      total [#.................................................]  2.00%
# this epoch [##############################....................] 61.95%
#       6000 iter, 1 epoch / 300000 iterations
#    0.18741 iters/sec. Estimated time to finish: 18 days, 3:45:31.735019.
#      total [#.................................................]  2.00%
# this epoch [###############################...................] 62.09%
#       6005 iter, 1 epoch / 300000 iterations
#     0.1873 iters/sec. Estimated time to finish: 18 days, 4:01:11.164627.
#      total [#.................................................]  2.00%
# this epoch [###############################...................] 62.22%
#       6010 iter, 1 epoch / 300000 iterations
#    0.18727 iters/sec. Estimated time to finish: 18 days, 4:05:08.132787.
#      total [#.................................................]  2.00%
# this epoch [###############################...................] 62.36%
#       6015 iter, 1 epoch / 300000 iterations
#    0.18752 iters/sec. Estimated time to finish: 18 days, 3:28:56.679270.
#      total [#.................................................]  2.01%
# this epoch [###############################...................] 62.49%
#       6020 iter, 1 epoch / 300000 iterations
#    0.18742 iters/sec. Estimated time to finish: 18 days, 3:42:35.902676.
#      total [#.................................................]  2.01%
# this epoch [###############################...................] 62.63%
#       6025 iter, 1 epoch / 300000 iterations
#    0.18738 iters/sec. Estimated time to finish: 18 days, 3:48:03.265960.
#      total [#.................................................]  2.01%
# this epoch [###############################...................] 62.76%
#       6030 iter, 1 epoch / 300000 iterations
#    0.18738 iters/sec. Estimated time to finish: 18 days, 3:46:58.758081.
#      total [#.................................................]  2.01%
# this epoch [###############################...................] 62.90%
#       6035 iter, 1 epoch / 300000 iterations
#    0.18736 iters/sec. Estimated time to finish: 18 days, 3:49:48.287439.
#      total [#.................................................]  2.01%
# this epoch [###############################...................] 63.03%
#       6040 iter, 1 epoch / 300000 iterations
#     0.1874 iters/sec. Estimated time to finish: 18 days, 3:43:26.726514.
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.17%
#       6045 iter, 1 epoch / 300000 iterations
#     0.1873 iters/sec. Estimated time to finish: 18 days, 3:57:45.372504.
# 6050        0.562437       0.0486484
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.30%
#       6050 iter, 1 epoch / 300000 iterations
#    0.18713 iters/sec. Estimated time to finish: 18 days, 4:20:22.782148.
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.44%
#       6055 iter, 1 epoch / 300000 iterations
#    0.18708 iters/sec. Estimated time to finish: 18 days, 4:27:13.484182.
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.57%
#       6060 iter, 1 epoch / 300000 iterations
#    0.18707 iters/sec. Estimated time to finish: 18 days, 4:27:39.343462.
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.71%
#       6065 iter, 1 epoch / 300000 iterations
#    0.18704 iters/sec. Estimated time to finish: 18 days, 4:32:12.224971.
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.84%
#       6070 iter, 1 epoch / 300000 iterations
#    0.18701 iters/sec. Estimated time to finish: 18 days, 4:35:05.353600.
#      total [#.................................................]  2.02%
# this epoch [###############################...................] 63.98%
#       6075 iter, 1 epoch / 300000 iterations
#    0.18693 iters/sec. Estimated time to finish: 18 days, 4:45:59.252542.
#      total [#.................................................]  2.03%
# this epoch [################################..................] 64.11%
#       6080 iter, 1 epoch / 300000 iterations
#    0.18691 iters/sec. Estimated time to finish: 18 days, 4:49:02.329804.
#      total [#.................................................]  2.03%
# this epoch [################################..................] 64.25%
#       6085 iter, 1 epoch / 300000 iterations
#    0.18687 iters/sec. Estimated time to finish: 18 days, 4:53:45.996362.
#      total [#.................................................]  2.03%
# this epoch [################################..................] 64.38%
#       6090 iter, 1 epoch / 300000 iterations
#     0.1869 iters/sec. Estimated time to finish: 18 days, 4:48:39.031377.
#      total [#.................................................]  2.03%
# this epoch [################################..................] 64.52%
#       6095 iter, 1 epoch / 300000 iterations
#    0.18681 iters/sec. Estimated time to finish: 18 days, 5:01:36.616505.
# 6100        0.573752       0.0462208
#      total [#.................................................]  2.03%
# this epoch [################################..................] 64.65%
#       6100 iter, 1 epoch / 300000 iterations
#    0.18674 iters/sec. Estimated time to finish: 18 days, 5:10:56.190967.
#      total [#.................................................]  2.04%
# this epoch [################################..................] 64.79%
#       6105 iter, 1 epoch / 300000 iterations
#    0.18666 iters/sec. Estimated time to finish: 18 days, 5:22:01.098569.
#      total [#.................................................]  2.04%
# this epoch [################################..................] 64.92%
#       6110 iter, 1 epoch / 300000 iterations
#    0.18633 iters/sec. Estimated time to finish: 18 days, 6:07:42.338065.
#      total [#.................................................]  2.04%
# this epoch [################################..................] 65.06%
#       6115 iter, 1 epoch / 300000 iterations
#    0.18629 iters/sec. Estimated time to finish: 18 days, 6:12:18.687372.
#      total [#.................................................]  2.04%
# this epoch [################################..................] 65.19%
#       6120 iter, 1 epoch / 300000 iterations
#    0.18608 iters/sec. Estimated time to finish: 18 days, 6:42:04.018954.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9475c0d2bd5c> in <module>()
# ----> 1 model.learn()
#
# /Users/yoshidayuuki/Documents/bitbucket/al4bb/sound/mimicopynet/mimicopynet/model/BasicCNN.py in learn(self)
#     153         input_cnl: 画像のチャンネル（CQTの絶対値を使うなら1,実部と虚部を使うなら2)
#     154         '''
# --> 155         self.model = BasicCNN_(input_cnl=input_cnl)
#     156         if gpu is not None:
#     157             cuda.get_device(gpu).use()
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/training/trainer.py in run(self)
#     294                 self.observation = {}
#     295                 with reporter.scope(self.observation):
# --> 296                     update()
#     297                     for name, entry in extensions:
#     298                         if entry.trigger(self):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/training/updater.py in update(self)
#     221
#     222         """
# --> 223         self.update_core()
#     224         self.iteration += 1
#     225
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/training/updater.py in update_core(self)
#     232
#     233         if isinstance(in_arrays, tuple):
# --> 234             optimizer.update(loss_func, *in_arrays)
#     235         elif isinstance(in_arrays, dict):
#     236             optimizer.update(loss_func, **in_arrays)
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/optimizer.py in update(self, lossfun, *args, **kwds)
#     530             else:
#     531                 self.target.zerograds()
# --> 532             loss.backward()
#     533             del loss
#     534
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/variable.py in backward(self, retain_grad)
#     716             func.output_data = tuple(
#     717                 [None if y is None else y.data for y in outputs])
# --> 718             gxs = func.backward(in_data, out_grad)
#     719             assert len(gxs) == len(in_data)
#     720             if not getattr(func, '_retain_after_backward', False):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/function.py in backward(self, inputs, grad_outputs)
#     390             return self.backward_gpu(inputs, grad_outputs)
#     391         else:
# --> 392             return self.backward_cpu(inputs, grad_outputs)
#     393
#     394     def backward_cpu(self, inputs, grad_outputs):
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/chainer/functions/connection/convolution_2d.py in backward_cpu(self, inputs, grad_outputs)
#     190         gW = numpy.tensordot(
#     191             gy, self.col, ((0, 2, 3), (0, 4, 5))).astype(W.dtype, copy=False)
# --> 192         gcol = numpy.tensordot(W, gy, (0, 1)).astype(x.dtype, copy=False)
#     193         gcol = numpy.rollaxis(gcol, 3)
#     194         gx = conv.col2im_cpu(gcol, self.sy, self.sx, self.ph, self.pw, h, w)
#
# /Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/numpy/core/numeric.py in tensordot(a, b, axes)
#    1337     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1338     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1339     res = dot(at, bt)
#    1340     return res.reshape(olda + oldb)
#    1341
#
# KeyboardInterrupt:

# %%
# Out:
#   0%|          | 0/248 [00:00<?, ?it/s]/Users/yoshidayuuki/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/pretty_midi-0.2.6-py3.5.egg/pretty_midi/pretty_midi.py:95: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
# 100%|██████████| 248/248 [00:41<00:00,  4.44it/s]
#  22%|██▏       | 98/444 [00:15<00:44,  7.69it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Beastie_Boys/Girls.mid]
# [Error]
# <class 'KeyError'>
# (-1, 255)
#  37%|███▋      | 166/444 [00:27<00:26, 10.46it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Billy_Joel/Movin__Out.mid]
# [Error]
# <class 'OSError'>
# data byte must be in range 0..127
#  39%|███▊      | 172/444 [00:28<00:34,  7.96it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Billy_Joel/Pressure.mid]
# [Error]
# <class 'OSError'>
# data byte must be in range 0..127
#  66%|██████▌   | 291/444 [00:49<00:20,  7.34it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Bomfunk_MCs/B_Boys_And_Fly_Girls.mid]
# [Error]
# <class 'OSError'>
# MThd not found. Probably not a MIDI file
#  66%|██████▌   | 293/444 [00:49<00:19,  7.91it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Bomfunk_MCs/Uprocking_Beats.mid]
# [Error]
# <class 'OSError'>
# MThd not found. Probably not a MIDI file
#  81%|████████▏ | 361/444 [01:00<00:08,  9.24it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Brian_McKnight/On_The_Down_Low.mid]
# [Error]
# <class 'EOFError'>
#  93%|█████████▎| 411/444 [01:07<00:04,  8.21it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Bryan_Adams/On_A_Day_Like_Today.mid]
# [Error]
# <class 'IndexError'>
# list index out of range
#  98%|█████████▊| 436/444 [01:11<00:01,  7.69it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Bush/Glycerine.mid]
# [Error]
# <class 'KeyError'>
# (-1, 255)
#  99%|█████████▉| 441/444 [01:12<00:00,  5.43it/s]
# [On loading /Users/yoshidayuuki/Downloads/midiworld/midifile/Busta_Rhymes/Woo_Hah.mid]
# [Error]
# <class 'OSError'>
# data byte must be in range 0..127
# 100%|██████████| 444/444 [01:13<00:00,  5.59it/s]

# %%
# Out:
# epoch       iteration   main/loss   main/precision  main/recall  main/fvalue  validation/main/loss  validation/main/precision  validation/main/recall  validation/main/fvalue  elapsed_time
# 0           10          0.682481    0.0193421       0.33514      0.0363802                                                                                                     14.669
# /Users/yoshidayuuki/Documents/bitbucket/al4bb/sound/mimicopynet/mimicopynet/chainer_utils/binary_classification_summary.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   f = 2 * p * r / (p + r)
# 0           20          0.643076    0.0196409       0.20501      nan                                                                                                           25.7214
# 0           30          0.555039    0.0317045       0.0367227    nan                                                                                                           37.7412
# /Users/yoshidayuuki/Documents/bitbucket/al4bb/sound/mimicopynet/mimicopynet/chainer_utils/binary_classification_summary.py:35: RuntimeWarning: invalid value encountered in long_scalars
#   p = tp / (tp + fp)
# 0           40          0.36609     nan             0            nan                                                                                                           49.0427
# 0           50          0.213184    nan             0            nan                                                                                                           60.4196
# 0           60          0.119871    nan             0            nan                                                                                                           69.3281
# 0           70          0.10026     nan             0            nan                                                                                                           79.696
# 0           80          0.07513     nan             0            nan                                                                                                           93.506
# 0           90          0.0721777   nan             0            nan                                                                                                           106.613
# 1           100         0.0802637   nan             0            nan          0.0727613             nan                        0                       nan                     219.972
# 1           110         0.0747421   nan             0            nan                                                                                                           267.526
# 1           120         0.0910392   nan             0            nan                                                                                                           280.741
# 1           130         0.0612717   nan             0            nan                                                                                                           293.545
# 1           140         0.0610749   nan             0            nan                                                                                                           307.668
# 1           150         0.0910602   nan             0            nan                                                                                                           321.529
# 1           160         0.0685521   nan             0            nan                                                                                                           333.469
# 1           170         0.070038    nan             0            nan                                                                                                           345.688
# 1           180         0.0732789   nan             0            nan                                                                                                           360.668
# 1           190         0.0753236   nan             0            nan                                                                                                           371.826
# 2           200         0.0915273   nan             0            nan          0.0697499             nan                        0                       nan                     469.206
# 2           210         0.0796554   nan             0            nan                                                                                                           513.163
# 2           220         0.0892323   nan             0            nan                                                                                                           522.273
# 2           230         0.0897702   nan             0            nan                                                                                                           531.265
# 2           240         0.0945568   nan             0            nan                                                                                                           541.125
# 2           250         0.0674989   nan             0            nan                                                                                                           552.037
# 2           260         0.108162    nan             0            nan                                                                                                           563.277
# 98          9880        0.0543894   0.645833        0.220476     0.306607                                                                                                      27297.1
# 98          9890        0.0392551   0.81746         0.312883     0.434395                                                                                                      27310.3
# 99          9900        0.0558902   0.826667        0.269573     0.388562     0.036132              nan                        nan                     nan                     27436.3
# 99          9910        0.0467086   0.767143        0.232617     0.345309                                                                                                      27487.6
# 99          9920        0.0545127   0.719167        0.250353     0.345006                                                                                                      27501.3
# 99          9930        0.0495002   0.751429        0.249722     0.346557                                                                                                      27514.8
# 99          9940        0.0451381   0.77579         0.29266      0.400564                                                                                                      27529.2
# 99          9950        0.035166    0.633333        0.209914     nan                                                                                                           27542.3
# 99          9960        0.0336726   0.717857        0.217748     0.328071                                                                                                      27557
# 99          9970        0.0368069   nan             0.236545     nan                                                                                                           27570.1
# 99          9980        0.0397568   0.622222        0.207468     nan                                                                                                           27584.7
# 99          9990        0.0493222   0.709048        0.197335     0.282122                                                                                                      27599.5
# 100         10000       0.0296401   0.658889        0.258221     0.349521     0.038383              nan                        0.198477                nan                     27727.2

# %% [markdown]
# ## 以下，デバッグ

# %%
md = mcn.data.MidiDataset(
    midis=glob.glob('/Users/yoshidayuuki/Downloads/midiworld/midifile/Darude/Sandstorm.mid'),
    size=1000,
    sf2_path=soundfont_path,
    length_sec=3.0, allow_drum=False, num_part=1, num_channel=1, skip_silence=0.9
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# 1 MIDI files are successfully loaded.

# %%
w, s = md.get_example(114514, verbose=True)
# Out:
# position (sec): 50.1-53.1 (total: 244.9)
# parts: [4] (total: 12)
#     [4] program: 87, name:
# synthesizing wave: 0.070 sec
# fetching score: 0.009 sec
# (silence then skipped)
# position (sec): 14.8-17.8 (total: 244.9)
# parts: [3] (total: 12)
#     [3] program: 50, name:
# synthesizing wave: 0.085 sec
# fetching score: 0.008 sec
# (silence then skipped)
# position (sec): 40.3-43.3 (total: 244.9)
# parts: [7] (total: 12)
#     [7] program: 109, name:
# synthesizing wave: 0.100 sec
# fetching score: 0.028 sec

# %%
plt.figure(figsize=(20,15))
plt.subplot(311)
plt.plot(w[:,0])
plt.subplot(312)
plt.imshow(s[0], origin='lower')
plt.subplot(313)
plt.imshow(s[1], origin='lower')
plt.show()

# %%
from chainer import Chain, ChainList, cuda, gradient_check, Function, Link, \
    optimizers, serializers, utils, Variable, dataset, datasets, using_config, training, iterators
from chainer.training import extensions
from chainer import functions as F
from chainer import links as La

# %%
# %autoreload

# %%
from mimicopynet.model.nocqt.model import Net
net = Net(num_channel=1, wave_samples=44100, score_samples=100)

# %%
x = Variable(np.random.randn(2, 1, 44100).astype(np.float32))

# %%
y = net(x)

# %%
from mimicopynet.chainer_utils import sigmoid_cross_entropy

# %%
y = Variable(np.array([[-0.8, -0.8],[0.8, -0.8]],dtype=np.float32))
t = Variable(np.array([[1, 1],[0, 1]],dtype=np.int32))

# %%
loss = sigmoid_cross_entropy(y, t, class_weight=np.array([1.0, 1.0]))

# %%
loss2 = F.sigmoid_cross_entropy(y, t)

# %%
loss, loss2
# Out:
# (variable(1.1711006), variable(1.1711006))
